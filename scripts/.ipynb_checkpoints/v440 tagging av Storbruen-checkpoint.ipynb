# %%
import ifcopenshell as ios 
import requests 
import json

# %%
file = ios.open("../modellfiler/Storbruen.ifc")

# %%
products=file.by_type("IfcProduct")
len(products)
# Out:
# 908

# %%
slabs = file.by_type("IfcSlab")
# Out:
# #150155=IfcPropertySet('2gSmt5QQzCPRoYEMCHlq5c',#42,'Properties',$,(#150153,#150154))

# %%
def get_material(ifcObject):
    assert ifcObject.is_a("IfcObject")
    if ifcObject.HasAssociations != ():
        material = ifcObject.HasAssociations[0].RelatingMaterial.Name
    else:
        material = None
    return material

# %%
## function to take an IfcProduct object and print out some info about it
# ref.: https://standards.buildingsmart.org/IFC/RELEASE/IFC2x3/TC1/HTML/ifckernel/lexical/ifcproduct.htm
def print_IfcObject(ifcObject): 
    assert ifcObject.is_a("IfcObject")
    # type
    ifcType = ifcObject.is_a()
    print(f"Ifc type:\t {ifcType}")
    # root attributes
    guid = ifcObject.GlobalId
    print(f"Guid:\t\t {guid}")
    name = ifcObject.Name
    print(f"Name:\t\t {name}")
    description = ifcObject.Description
    print(f"Description:\t {description}")
    
    # Material 
    material = get_material(ifcObject)
    print(f"Material:\t {material}")
    
    # Object attributes
    object_type = ifcObject.ObjectType
    
    #Tag attributes 
    if ifcObject.is_a("IfcElement"):
        tag = ifcObject.Tag
    else:
        tag = None
    print(f"Tag:\t {tag}")
    
    print(f"Type:\t\t {object_type}\n")
    #return ifcType,guid,name,description,material,object_type

# %%
# materialtyper brukt 
material_types = set([get_material(product) for product in products])
material_types
# Out:
# {'CONCRETE/B45', None, 'STEEL/S355NL'}

# %%
product_types = set([product.is_a() for product in products])
print(product_types)
for product in products:
    print_IfcObject(product)
# Out:
# {'IfcColumn', 'IfcSite', 'IfcBuilding', 'IfcFooting', 'IfcSlab', 'IfcPile', 'IfcBuildingStorey', 'IfcWall', 'IfcPlate'}
# Ifc type:	 IfcSite
# Guid:		 0d7Fg7GZj2MxRJj7fJ8JTP
# Name:		 Markusplassen
# Description:	 None
# Material:	 None
# Tag:	 None
# Type:		 None
#
# Ifc type:	 IfcBuilding
# Guid:		 3hly7pMOTAjgSPAEkiYxWH
# Name:		 Storbruen
# Description:	 None
# Material:	 None
# Tag:	 None
# Type:		 None
#
# Ifc type:	 IfcBuildingStorey
# Guid:		 0cBzSKq19B2fg9breFcxZK
# Name:		 Bru
# Description:	 None
# Material:	 None
# Tag:	 None
# Type:		 None
#
# Ifc type:	 IfcWall
# Guid:		 2$g5PKLDbDcQ_QHQTROYUh
# Name:		 Landkar
# Description:	 OtHLGn-WTEah7oWDYBRV_g_10
# Material:	 CONCRETE/B45
# Tag:	 IDcb67dd68-d789-40d7-96cb-8e243a59cbca
# Type:		 OtHLGn-WTEah7oWDYBRV_g_10
#
# Ifc type:	 IfcWall
# Guid:		 1eU5UnQ5f66wyi_$sXLJFy
# Name:		 Landkar
# Description:	 OtHLGn-WTEah7oWDYBRV_g_13
# Material:	 CONCRETE/B45
# Tag:	 IDd22590c1-2cb1-49a8-85d5-4ef82864f831
# Type:		 OtHLGn-WTEah7oWDYBRV_g_13
#
# Ifc type:	 IfcWall
# Guid:		 2tXynej51CR904PE0qycS5
# Name:		 Landkar
# Description:	 OtHLGn-WTEah7oWDYBRV_g_4
# Material:	 CONCRETE/B45
# Tag:	 IDe84730f9-c47b-41c9-8bbc-045c610a1d1c
# Type:		 OtHLGn-WTEah7oWDYBRV_g_4
#
# Ifc type:	 IfcWall
# Guid:		 0LvroMxmj1dAnZ4E132eac
# Name:		 Landkar
# Description:	 OtHLGn-WTEah7oWDYBRV_g_7
# Material:	 CONCRETE/B45
# Tag:	 ID658f1e34-1014-4a98-a68e-e0b93bdc02fe
# Type:		 OtHLGn-WTEah7oWDYBRV_g_7
#
# Ifc type:	 IfcPlate
# Guid:		 0eMAnEyALC5AdbsQWnCzaR
# Name:		 brubjelke
# Description:	 PL16*5457
# Material:	 STEEL/S355NL
# Tag:	 IDe0f30a8c-b121-4d20-b090-342c4d5f4d17
# Type:		 PL16*5457
#
# Ifc type:	 IfcPlate
# Guid:		 3B$CNXQ_j51hid5vU3vyc9
# Name:		 brubjelke
# Description:	 PL25*2200
# Material:	 STEEL/S355NL
# Tag:	 ID1a3dbc33-3d86-4eec-bb85-204874e287bb
# Type:		 PL25*2200
#
# Ifc type:	 IfcPlate
# Guid:		 0WUeZFnhX5bfQFaTMi6SZk
# Name:		 brubjelke
# Description:	 PL16*5457
# Material:	 STEEL/S355NL
# Tag:	 ID87d8d204-dfa0-4728-b10a-7b5741daa551
# Type:		 PL16*5457
#
# Ifc type:	 IfcPlate
# Guid:		 08a840IKj2bwB9_VtYY26x
# Name:		 brubjelke
# Description:	 PL30*3500
# Material:	 STEEL/S355NL
# Tag:	 ID5ca53d20-75b6-4525-ac57-f4a0d7c01565
# Type:		 PL30*3500
#
# Ifc type:	 IfcPlate
# Guid:		 0VvkM2DZf9uBcnt7a0tNeg
# Name:		 brubjelke
# Description:	 PL25*2200
# Material:	 STEEL/S355NL
# Tag:	 ID8902a524-7b4d-4fa0-a97d-9d75277fdeec
# Type:		 PL25*2200
#
# Ifc type:	 IfcPlate
# Guid:		 0psPO_h3zCzQ3sUtUh0prT
# Name:		 brubjelke
# Description:	 PL16*5457
# Material:	 STEEL/S355NL
# Tag:	 IDd6de2cd3-9e0c-40bf-96df-fdb12589cf7f
# Type:		 PL16*5457
#
# Ifc type:	 IfcPlate
# Guid:		 0KotGaQsbAL9qv$Ed0MIAM
# Name:		 brubjelke
# Description:	 PL30*3500
# Material:	 STEEL/S355NL
# Tag:	 IDf8094eec-6ccd-4691-966f-5f0be26a85ad
# Type:		 PL30*3500
#
# Ifc type:	 IfcPlate
# Guid:		 1WdhPRWsL3zxUgIYqvZqcj
# Name:		 brubjelke
# Description:	 PL25*2200
# Material:	 STEEL/S355NL
# Tag:	 IDe3fd1d33-2e28-44c3-9153-95bac6df3a2a
# Type:		 PL25*2200
#
# Ifc type:	 IfcPlate
# Guid:		 1Xzraz06jC19DIwep9H_M$
# Name:		 brubjelke
# Description:	 PL30*3500
# Material:	 STEEL/S355NL
# Tag:	 ID9ab22cd6-6a9b-40f4-b01e-40cb2617a427
# Type:		 PL30*3500
#
# Ifc type:	 IfcPlate
# Guid:		 1sYRNlBOf0vfXxbO0OsmeB
# Name:		 brubjelke
# Description:	 PL16*5456
# Material:	 STEEL/S355NL
# Tag:	 IDd65f5cbf-31ee-4647-9930-0e2bb3930811
# Type:		 PL16*5456
#
# Ifc type:	 IfcPlate
# Guid:		 0fSfm8i9L9WuHDQm3qMGm7
# Name:		 brubjelke
# Description:	 PL25*2200
# Material:	 STEEL/S355NL
# Tag:	 ID30790be9-a59c-4ab1-bcba-fde27092f992
# Type:		 PL25*2200
#
# Ifc type:	 IfcPlate
# Guid:		 2Kwz2BJr93PvikoiJxhzpj
# Name:		 brubjelke
# Description:	 PL30*3500
# Material:	 STEEL/S355NL
# Tag:	 ID1b88e28b-1ff1-4b9e-b8de-ea46a5bf6d91
# Type:		 PL30*3500
#
# Ifc type:	 IfcPlate
# Guid:		 07tVbhM91DqArsK8xgK8Am
# Name:		 brubjelke
# Description:	 PL16*5457
# Material:	 STEEL/S355NL
# Tag:	 ID5f373f62-3016-4d6d-96a0-4984fadb9398
# Type:		 PL16*5457
#
# Ifc type:	 IfcPlate
# Guid:		 2xBppliPv7URF4Z1Ss8Xq4
# Name:		 brubjelke
# Description:	 PL25*2200
# Material:	 STEEL/S355NL
# Tag:	 IDb094e36e-7c6e-431c-ae04-b0deb1b1f9bd
# Type:		 PL25*2200
#
# Ifc type:	 IfcPlate
# Guid:		 3RWox_WnH8PeKkQpclVCel
# Name:		 brubjelke
# Description:	 PL30*3500
# Material:	 STEEL/S355NL
# Tag:	 ID22505f14-69e7-4f9f-bda6-32fad6992f95
# Type:		 PL30*3500
#
# Ifc type:	 IfcPlate
# Guid:		 3e8znoLt15wRI82ZEr9395
# Name:		 brubjelke
# Description:	 PL16*5456
# Material:	 STEEL/S355NL
# Tag:	 ID748b6ae3-8a49-432c-a892-40d025fc9dd3
# Type:		 PL16*5456
#
# Ifc type:	 IfcPlate
# Guid:		 0RYa5Qb1r8pBNra2Gm_M9e
# Name:		 brubjelke
# Description:	 PL25*2200
# Material:	 STEEL/S355NL
# Tag:	 ID3be6ad4b-bf76-40d9-9bdc-71ddcb62569c
# Type:		 PL25*2200
#
# Ifc type:	 IfcPlate
# Guid:		 1xL7c2h3X2NR7FssWQJhTJ
# Name:		 brubjelke
# Description:	 PL30*3500
# Material:	 STEEL/S355NL
# Tag:	 ID88d36ae4-8b3a-4845-ac22-ac2f746d0395
# Type:		 PL30*3500
#
# Ifc type:	 IfcPlate
# Guid:		 0Y37mbohD2mg2whMFn61e7
# Name:		 brubjelke
# Description:	 PL16*5456
# Material:	 STEEL/S355NL
# Tag:	 ID7bb1811b-52b1-4e8e-b780-1c8ae6a8b6f3
# Type:		 PL16*5456
#
# Ifc type:	 IfcPlate
# Guid:		 1vo4d91kP2nOyPzAMZ87iB
# Name:		 brubjelke
# Description:	 PL25*2200
# Material:	 STEEL/S355NL
# Tag:	 ID7bfba851-d575-48c5-af57-aa02cac5f1be
# Type:		 PL25*2200
#
# Ifc type:	 IfcPlate
# Guid:		 2Scd8MfZzFReVPzFihCGsW
# Name:		 brubjelke
# Description:	 PL30*3500
# Material:	 STEEL/S355NL
# Tag:	 IDf535e715-cdd8-4674-85ac-06414120e70d
# Type:		 PL30*3500
#
# Ifc type:	 IfcPlate
# Guid:		 1HJ7A9Ol9FZOhRcIBxqU9L
# Name:		 brubjelke
# Description:	 PL16*5456
# Material:	 STEEL/S355NL
# Tag:	 ID79fd15d4-acb5-4d66-8d0f-c674c47a2793
# Type:		 PL16*5456
#
# Ifc type:	 IfcPlate
# Guid:		 10IcAijTX7p9NAaTEaYN07
# Name:		 brubjelke
# Description:	 PL25*2200
# Material:	 STEEL/S355NL
# Tag:	 IDe5f022ae-5e30-4a2f-9eab-7943c76c41f9
# Type:		 PL25*2200
#
# Ifc type:	 IfcPlate
# Guid:		 0fXxgRjizF39phQDGFrIcX
# Name:		 brubjelke
# Description:	 PL30*3500
# Material:	 STEEL/S355NL
# Tag:	 IDfc55df0c-0269-4461-ba18-2aabbe43527b
# Type:		 PL30*3500
#
# Ifc type:	 IfcPlate
# Guid:		 00JwC0lVH4jPcNFT$Ht3NS
# Name:		 brubjelke
# Description:	 PL16*5456
# Material:	 STEEL/S355NL
# Tag:	 ID5ae7ce35-f48d-47ea-b203-df7f85f7e0ce
# Type:		 PL16*5456
#
# Ifc type:	 IfcPlate
# Guid:		 3rKy5jSh97gfOrdyM52Waq
# Name:		 brubjelke
# Description:	 PL25*2200
# Material:	 STEEL/S355NL
# Tag:	 ID3cf9610a-01f8-49be-882d-3ec6dcf13265
# Type:		 PL25*2200
#
# Ifc type:	 IfcPlate
# Guid:		 1qTo5uV1DC2uTKrl39mADA
# Name:		 brubjelke
# Description:	 PL30*3500
# Material:	 STEEL/S355NL
# Tag:	 ID3987673d-5103-443c-b5c8-ff4d57484965
# Type:		 PL30*3500
#
# Ifc type:	 IfcPlate
# Guid:		 2jZwyHaqfFxuGPmmMl$nRu
# Name:		 brubjelke
# Description:	 PL16*5456
# Material:	 STEEL/S355NL
# Tag:	 ID0c4bb663-06e1-456f-a782-75e8d4a1ca2f
# Type:		 PL16*5456
#
# Ifc type:	 IfcPlate
# Guid:		 0XWOeMAdv2yglYmo8KTbp4
# Name:		 brubjelke
# Description:	 PL25*2200
# Material:	 STEEL/S355NL
# Tag:	 ID2bf7b851-eafd-4406-a91e-6ddf1ffd2d03
# Type:		 PL25*2200
#
# Ifc type:	 IfcPlate
# Guid:		 2ZxBeWBOfEJRjoJTRHveCO
# Name:		 brubjelke
# Description:	 PL30*3500
# Material:	 STEEL/S355NL
# Tag:	 ID92517946-263a-47b1-acdf-fa9fbb75e02d
# Type:		 PL30*3500
#
# Ifc type:	 IfcPlate
# Guid:		 3GK2XsHmzCmfjyE5i$GNvH
# Name:		 brubjelke
# Description:	 PL16*5456
# Material:	 STEEL/S355NL
# Tag:	 IDb220e90d-f044-44b5-bda4-47eaf400de8f
# Type:		 PL16*5456
#
# Ifc type:	 IfcPlate
# Guid:		 2PePoJA453AQ6UaY3D9stO
# Name:		 brubjelke
# Description:	 PL25*2200
# Material:	 STEEL/S355NL
# Tag:	 ID6c18dcb7-aa83-4473-b691-79a9ee8aaf61
# Type:		 PL25*2200
#
# Ifc type:	 IfcPlate
# Guid:		 21oZUrEkrCG8vlyoI_L9jt
# Name:		 brubjelke
# Description:	 PL30*3500
# Material:	 STEEL/S355NL
# Tag:	 ID6f7607f7-aca7-4ef0-bf7b-ea4aced64ecb
# Type:		 PL30*3500
#
# Ifc type:	 IfcPlate
# Guid:		 1lo8G0u2n4YeHs4U_EV4Xr
# Name:		 brubjelke
# Description:	 PL16*5456
# Material:	 STEEL/S355NL
# Tag:	 IDc0d37583-4728-4974-a7c3-5960fd1f9931
# Type:		 PL16*5456
#
# Ifc type:	 IfcPlate
# Guid:		 3OUjDeY3TBfuzBO3k7gNlS
# Name:		 brubjelke
# Description:	 PL25*2200
# Material:	 STEEL/S355NL
# Tag:	 ID8a74fa7f-9058-42c3-a74e-d44effbd217b
# Type:		 PL25*2200
#
# Ifc type:	 IfcPlate
# Guid:		 1PK4nkHi58xBskN_Axudhw
# Name:		 brubjelke
# Description:	 PL30*3500
# Material:	 STEEL/S355NL
# Tag:	 IDcb6054ab-750d-4d16-98cc-892075c4e8fd
# Type:		 PL30*3500
#
# Ifc type:	 IfcPlate
# Guid:		 2PYTsTJOH2PvX8gUdnYiRv
# Name:		 brubjelke
# Description:	 PL16*5456
# Material:	 STEEL/S355NL
# Tag:	 ID5ffa6cc8-23cb-4c94-b7d6-2a3fe3bb1987
# Type:		 PL16*5456
#
# Ifc type:	 IfcPlate
# Guid:		 2WkoflfrX6a9GEfmQSKBsE
# Name:		 brubjelke
# Description:	 PL25*2200
# Material:	 STEEL/S355NL
# Tag:	 ID73f62850-4667-41ec-8893-1cfb8dbab599
# Type:		 PL25*2200
#
# Ifc type:	 IfcPlate
# Guid:		 0OTaOXBXf3CeCGcWHJ1HiJ
# Name:		 brubjelke
# Description:	 PL30*3500
# Material:	 STEEL/S355NL
# Tag:	 ID0422217f-c615-469b-854f-1b57c7b68913
# Type:		 PL30*3500
#
# Ifc type:	 IfcPlate
# Guid:		 03v0$3JA97BxNVJ3EfviAs
# Name:		 brubjelke
# Description:	 PL16*4949
# Material:	 STEEL/S355NL
# Tag:	 ID258f3251-3224-4c92-9bb8-c5204f965d09
# Type:		 PL16*4949
#
# Ifc type:	 IfcPlate
# Guid:		 1LtoJgc3f8BOVi3wYIWJ$j
# Name:		 brubjelke
# Description:	 PL25*2200
# Material:	 STEEL/S355NL
# Tag:	 IDbdd9200d-f753-45aa-a55d-ea060de95821
# Type:		 PL25*2200
#
# Ifc type:	 IfcPlate
# Guid:		 3wayEjm2XDSwdNhTo8MvJI
# Name:		 brubjelke
# Description:	 PL30*3500
# Material:	 STEEL/S355NL
# Tag:	 ID09e65130-996d-4a26-a1c1-3182d95b8f07
# Type:		 PL30*3500
#
# Ifc type:	 IfcPlate
# Guid:		 2WJJkwUsTAo96Y_i3ymW$z
# Name:		 brubjelke
# Description:	 PL16*5456
# Material:	 STEEL/S355NL
# Tag:	 ID381dca78-ec1e-4444-8033-836a33db7004
# Type:		 PL16*5456
#
# Ifc type:	 IfcPlate
# Guid:		 1uGO8EVln3VukurepYPvxD
# Name:		 brubjelke
# Description:	 PL25*2200
# Material:	 STEEL/S355NL
# Tag:	 ID9ce6501d-dc32-4b36-b2bf-b9b9cd06f40d
# Type:		 PL25*2200
#
# Ifc type:	 IfcPlate
# Guid:		 1NKIxnNev8KuV5ydZWB6Cn
# Name:		 brubjelke
# Description:	 PL30*3500
# Material:	 STEEL/S355NL
# Tag:	 IDf596b017-ab14-409b-87c7-c8c50d9e9f90
# Type:		 PL30*3500
#
# Ifc type:	 IfcPlate
# Guid:		 01K3h68frED80ilg78izd0
# Name:		 brubjelke
# Description:	 PL16*5456
# Material:	 STEEL/S355NL
# Tag:	 ID25189e73-4c2f-43d8-bcfd-5d7eb9325cf7
# Type:		 PL16*5456
#
# Ifc type:	 IfcPlate
# Guid:		 1_Lh49SA9DZezLUP5ykqwZ
# Name:		 brubjelke
# Description:	 PL25*2200
# Material:	 STEEL/S355NL
# Tag:	 ID963b41b8-99ea-447c-aef4-5f7c9c46e35c
# Type:		 PL25*2200
#
# Ifc type:	 IfcPlate
# Guid:		 2pnUIY7ivCVRjcvGXrp2XI
# Name:		 brubjelke
# Description:	 PL30*3500
# Material:	 STEEL/S355NL
# Tag:	 IDf7c5bf04-b4b4-420d-911e-885aa316216f
# Type:		 PL30*3500
#
# Ifc type:	 IfcPlate
# Guid:		 3_oEfu_Pr0PQVHF44BvVYg
# Name:		 brubjelke
# Description:	 PL16*5456
# Material:	 STEEL/S355NL
# Tag:	 ID9badab6d-5ccb-4167-91bf-9d8494feb02f
# Type:		 PL16*5456
#
# Ifc type:	 IfcPlate
# Guid:		 0JRV_56zrFYgIiagj_JO4c
# Name:		 brubjelke
# Description:	 PL25*2200
# Material:	 STEEL/S355NL
# Tag:	 ID28e55caa-1c28-4fe6-980b-47d4ec19660e
# Type:		 PL25*2200
#
# Ifc type:	 IfcPlate
# Guid:		 1SsKsxgSL8jvSHFaJOj7DB
# Name:		 brubjelke
# Description:	 PL30*3500
# Material:	 STEEL/S355NL
# Tag:	 IDd3896d60-72f6-406d-b935-7907939dad6c
# Type:		 PL30*3500
#
# Ifc type:	 IfcPlate
# Guid:		 0tv1JwAnP16u43nknuY5zm
# Name:		 brubjelke
# Description:	 PL16*5456
# Material:	 STEEL/S355NL
# Tag:	 IDa2fce66d-9a59-469b-b80e-4e422f9f4ce5
# Type:		 PL16*5456
#
# Ifc type:	 IfcPlate
# Guid:		 3ru_inBMf8DAfTdmedE5ia
# Name:		 brubjelke
# Description:	 PL25*2200
# Material:	 STEEL/S355NL
# Tag:	 IDafd9675a-20e6-479c-908b-359b483f8913
# Type:		 PL25*2200
#
# Ifc type:	 IfcPlate
# Guid:		 0PYi7dlv19NBHK14KaMGsX
# Name:		 brubjelke
# Description:	 PL16*5456
# Material:	 STEEL/S355NL
# Tag:	 IDdbbee357-aad1-4e75-ac7d-e946f7e07134
# Type:		 PL16*5456
#
# Ifc type:	 IfcPlate
# Guid:		 31zFGpWcH5MgQx5g8qWEXn
# Name:		 brubjelke
# Description:	 PL30*3500
# Material:	 STEEL/S355NL
# Tag:	 ID8bc29898-4532-4bda-9bb3-6d2a313a7cd5
# Type:		 PL30*3500
#
# Ifc type:	 IfcPlate
# Guid:		 3DXj0lltnD3gYB72OrxCsc
# Name:		 brubjelke
# Description:	 PL25*2200
# Material:	 STEEL/S355NL
# Tag:	 IDf7e5fa18-4f82-430c-a2c8-c7caf4ff9a58
# Type:		 PL25*2200
#
# Ifc type:	 IfcPlate
# Guid:		 07XShHM1DDeRFoPZ7Gr9uB
# Name:		 brubjelke
# Description:	 PL16*5456
# Material:	 STEEL/S355NL
# Tag:	 ID4c0e1f20-fb1d-444f-9288-c37c28c8bef9
# Type:		 PL16*5456
#
# Ifc type:	 IfcPlate
# Guid:		 3dpSbiY7L1ifvtNWRJkbA0
# Name:		 brubjelke
# Description:	 PL30*3500
# Material:	 STEEL/S355NL
# Tag:	 ID7ed80a3d-ecaf-4c3c-89a6-94347a07bbaf
# Type:		 PL30*3500
#
# Ifc type:	 IfcPlate
# Guid:		 3wSKP4bMXCyRqyoXJGXD6n
# Name:		 brubjelke
# Description:	 PL25*2200
# Material:	 STEEL/S355NL
# Tag:	 IDed85f5a7-fffd-4648-affb-53896d277d4c
# Type:		 PL25*2200
#
# Ifc type:	 IfcPlate
# Guid:		 1ABwBUUHn8$OVPHJoR_Cr6
# Name:		 brubjelke
# Description:	 PL16*5456
# Material:	 STEEL/S355NL
# Tag:	 ID8c11d903-1b8f-4ec5-bde8-b97c363a13cf
# Type:		 PL16*5456
#
# Ifc type:	 IfcPlate
# Guid:		 0w6ASDIzP0i8lpG0NVHWI9
# Name:		 brubjelke
# Description:	 PL30*3500
# Material:	 STEEL/S355NL
# Tag:	 ID16adcd1e-329f-4003-bc8e-acc2c6cd2319
# Type:		 PL30*3500
#
# Ifc type:	 IfcPlate
# Guid:		 2tNceE86T2LQZzC_W314h4
# Name:		 brubjelke
# Description:	 PL25*2200
# Material:	 STEEL/S355NL
# Tag:	 ID48b21988-5dcd-467d-82ae-a9da1047b2f4
# Type:		 PL25*2200
#
# Ifc type:	 IfcPlate
# Guid:		 2W$iMTt31Adv7_VmayG1sV
# Name:		 brubjelke
# Description:	 PL16*5456
# Material:	 STEEL/S355NL
# Tag:	 IDdd90bc66-c06e-4887-9700-6bf0298048ec
# Type:		 PL16*5456
#
# Ifc type:	 IfcPlate
# Guid:		 1$Ev7lafH4WPfU3x78eUGd
# Name:		 brubjelke
# Description:	 PL30*3500
# Material:	 STEEL/S355NL
# Tag:	 ID1597506d-819f-4b2e-8cd6-89750648e2b8
# Type:		 PL30*3500
#
# Ifc type:	 IfcPlate
# Guid:		 1V97_x_fP4Hv6WTlDq4Tou
# Name:		 brubjelke
# Description:	 PL25*2200
# Material:	 STEEL/S355NL
# Tag:	 ID7281df9e-b6a5-470d-af94-933c37cec049
# Type:		 PL25*2200
#
# Ifc type:	 IfcPlate
# Guid:		 3Dct9sAMH5qRyvlqfKqxlf
# Name:		 brubjelke
# Description:	 PL16*4858
# Material:	 STEEL/S355NL
# Tag:	 ID7ed28299-f354-400c-a8f1-2380c73ad584
# Type:		 PL16*4858
#
# Ifc type:	 IfcPlate
# Guid:		 2b38dlrJn0PA6Lip1k2386
# Name:		 brubjelke
# Description:	 PL30*3500
# Material:	 STEEL/S355NL
# Tag:	 ID84c9a702-2a3a-4a25-a1c1-e5e8fbadb607
# Type:		 PL30*3500
#
# Ifc type:	 IfcPlate
# Guid:		 2Uts87BxPF2PMHZzeJfA1T
# Name:		 brubjelke
# Description:	 PL25*2200
# Material:	 STEEL/S355NL
# Tag:	 IDc88acf72-49d7-48f3-b6f7-8de4cd80ace2
# Type:		 PL25*2200
#
# Ifc type:	 IfcPlate
# Guid:		 0BEA6QWmb14Bl2RNmadWKh
# Name:		 brubjelke
# Description:	 PL16*5456
# Material:	 STEEL/S355NL
# Tag:	 ID2594200d-dcea-458c-a0b9-b0229f257803
# Type:		 PL16*5456
#
# Ifc type:	 IfcPlate
# Guid:		 294w7jTIX8mwfyZgV$qm4E
# Name:		 brubjelke
# Description:	 PL30*3500
# Material:	 STEEL/S355NL
# Tag:	 IDcc6c1b27-094c-4c30-a4a1-90c097d7b254
# Type:		 PL30*3500
#
# Ifc type:	 IfcPlate
# Guid:		 3JwoniKcfFieNkMsX89pFQ
# Name:		 brubjelke
# Description:	 PL25*2200
# Material:	 STEEL/S355NL
# Tag:	 IDd93887ee-ccc3-4106-a4bd-b2eabed2a3f1
# Type:		 PL25*2200
#
# Ifc type:	 IfcPlate
# Guid:		 21jG5X0ufBBBloiFCph3oo
# Name:		 brubjelke
# Description:	 PL16*5456
# Material:	 STEEL/S355NL
# Tag:	 IDa00be322-745b-466a-a348-0db2eb6d2237
# Type:		 PL16*5456
#
# Ifc type:	 IfcPlate
# Guid:		 094mg6iBjFBQkGu0MjbjXi
# Name:		 brubjelke
# Description:	 PL30*3500
# Material:	 STEEL/S355NL
# Tag:	 IDd95936b4-0b05-4ee8-9e4a-fbf583c8057c
# Type:		 PL30*3500
#
# Ifc type:	 IfcPlate
# Guid:		 21KWpSbXX7ReaQHJw$8jnp
# Name:		 brubjelke
# Description:	 PL25*2200
# Material:	 STEEL/S355NL
# Tag:	 IDc2a58fff-3ba9-48d1-a930-e69b8a47f9cc
# Type:		 PL25*2200
#
# Ifc type:	 IfcPlate
# Guid:		 1rGyFWBt16WAqjSEWgN2za
# Name:		 brubjelke
# Description:	 PL16*5456
# Material:	 STEEL/S355NL
# Tag:	 IDbc6ab817-0916-4c60-9cc3-f70d00bb807d
# Type:		 PL16*5456
#
# Ifc type:	 IfcPlate
# Guid:		 08DflwXLPAoeZ_dJ4FTGQ_
# Name:		 brubjelke
# Description:	 PL25*2200
# Material:	 STEEL/S355NL
# Tag:	 ID124a84b4-126c-4b8b-809b-d7f8a19dd223
# Type:		 PL25*2200
#
# Ifc type:	 IfcPlate
# Guid:		 3dtsqIj3H2cOO$lI0AusTT
# Name:		 brubjelke
# Description:	 PL30*3500
# Material:	 STEEL/S355NL
# Tag:	 ID9b2e5cca-ffcf-4d35-b70c-e2dc8d6e22b9
# Type:		 PL30*3500
#
# Ifc type:	 IfcPlate
# Guid:		 0PRm6AeZf8QvSYUZxR4tV3
# Name:		 brubjelke
# Description:	 PL16*5456
# Material:	 STEEL/S355NL
# Tag:	 IDde6c9654-8a14-462e-90f1-c0aa6761e3e2
# Type:		 PL16*5456
#
# Ifc type:	 IfcPlate
# Guid:		 3zOg5FxY1DyfYhiW3tHoUj
# Name:		 brubjelke
# Description:	 PL25*2200
# Material:	 STEEL/S355NL
# Tag:	 IDa39adbd2-c7b2-42e0-bc1b-abb010610be6
# Type:		 PL25*2200
#
# Ifc type:	 IfcPlate
# Guid:		 3yP_AxSl19EeLpmWjBGq03
# Name:		 brubjelke
# Description:	 PL30*3500
# Material:	 STEEL/S355NL
# Tag:	 ID2ee6edc4-936b-4684-a726-722b7faaa3a1
# Type:		 PL30*3500
#
# Ifc type:	 IfcPlate
# Guid:		 1SNxY9jLTCC8qXNcGHrLuq
# Name:		 brubjelke
# Description:	 PL16*5456
# Material:	 STEEL/S355NL
# Tag:	 IDeb386094-4b86-4169-a0de-d3c04fb6e43c
# Type:		 PL16*5456
#
# Ifc type:	 IfcPlate
# Guid:		 128lSdofH7ERyvkTeo7god
# Name:		 brubjelke
# Description:	 PL25*2200
# Material:	 STEEL/S355NL
# Tag:	 ID6decbf0f-997c-446e-8125-fe6ea5985912
# Type:		 PL25*2200
#
# Ifc type:	 IfcPlate
# Guid:		 2ek3XX_OD9fOTO0pmYqj9d
# Name:		 brubjelke
# Description:	 PL30*3500
# Material:	 STEEL/S355NL
# Tag:	 IDba66810c-d9a1-4713-b545-e6e182c60b0f
# Type:		 PL30*3500
#
# Ifc type:	 IfcPlate
# Guid:		 1uLt2$Cab6TRImOtP4VzNV
# Name:		 brubjelke
# Description:	 PL25*2200
# Material:	 STEEL/S355NL
# Tag:	 ID03569a3d-c872-4aa7-86f2-be66d6c9e3ce
# Type:		 PL25*2200
#
# Ifc type:	 IfcPlate
# Guid:		 1GX4TPnL13rB$jxgZmW1Fk
# Name:		 brubjelke
# Description:	 PL16*5456
# Material:	 STEEL/S355NL
# Tag:	 ID711ee64a-1875-4a91-81eb-1d78e5cf78b7
# Type:		 PL16*5456
#
# Ifc type:	 IfcPlate
# Guid:		 1k5Wmag$v1hfmkxL5ImTX1
# Name:		 brubjelke
# Description:	 PL30*3500
# Material:	 STEEL/S355NL
# Tag:	 ID769a1de6-1b83-45a2-8058-4a396772eb53
# Type:		 PL30*3500
#
# Ifc type:	 IfcPlate
# Guid:		 1Y_kF29Rv0qA_GAfowsV9Y
# Name:		 brubjelke
# Description:	 PL25*2200
# Material:	 STEEL/S355NL
# Tag:	 ID93349f68-a45d-4473-a27c-94c332429fef
# Type:		 PL25*2200
#
# Ifc type:	 IfcPlate
# Guid:		 2iNydxUo5538zLehn4ohp3
# Name:		 brubjelke
# Description:	 PL16*5456
# Material:	 STEEL/S355NL
# Tag:	 ID0811cfdc-6c2e-4f19-80ea-1fe72a82f369
# Type:		 PL16*5456
#
# Ifc type:	 IfcPlate
# Guid:		 0X9DadT_z7hhzWjIF2TUb3
# Name:		 brubjelke
# Description:	 PL30*3500
# Material:	 STEEL/S355NL
# Tag:	 IDeb483970-cd6c-4abe-b590-7a264d41f264
# Type:		 PL30*3500
#
# Ifc type:	 IfcPlate
# Guid:		 2ztYkb3cbF6utW7FvEf4rZ
# Name:		 brubjelke
# Description:	 PL25*2200
# Material:	 STEEL/S355NL
# Tag:	 ID2c350db1-570c-4453-b258-cbe0b5623604
# Type:		 PL25*2200
#
# Ifc type:	 IfcPlate
# Guid:		 12Udwc1cnDcBGrs2Y9xQdi
# Name:		 brubjelke
# Description:	 PL16*5456
# Material:	 STEEL/S355NL
# Tag:	 IDe53b48fb-2a6f-4e27-b022-9e9be278c06a
# Type:		 PL16*5456
#
# Ifc type:	 IfcPlate
# Guid:		 3_6ubI$0X6Me3$pgtYlZQb
# Name:		 brubjelke
# Description:	 PL30*3500
# Material:	 STEEL/S355NL
# Tag:	 ID3259be8e-244c-495d-82eb-4a04cc8ef160
# Type:		 PL30*3500
#
# Ifc type:	 IfcPlate
# Guid:		 1v8au4qUn2KwucJIg1cijC
# Name:		 brubjelke
# Description:	 PL25*2200
# Material:	 STEEL/S355NL
# Tag:	 IDfeb05a4c-de13-4dcc-a8bd-cca8e63a6a6f
# Type:		 PL25*2200
#
# Ifc type:	 IfcPlate
# Guid:		 3I_QsnZHDCuf8XqLay4BKs
# Name:		 brubjelke
# Description:	 PL16*5456
# Material:	 STEEL/S355NL
# Tag:	 ID70b9e66e-bb87-4997-b72a-d0ea12831e0d
# Type:		 PL16*5456
#
# Ifc type:	 IfcPlate
# Guid:		 1Ru5VWPMf7puPIygOg2HJK
# Name:		 brubjelke
# Description:	 PL30*3500
# Material:	 STEEL/S355NL
# Tag:	 IDd52f51bf-376d-4d20-90b8-fddcce60e05b
# Type:		 PL30*3500
#
# Ifc type:	 IfcPlate
# Guid:		 3pO0qd4Vz75BDHqU9D_E7Y
# Name:		 brubjelke
# Description:	 PL25*2200
# Material:	 STEEL/S355NL
# Tag:	 ID841d8b49-3e63-44a1-af4b-63dd634e186b
# Type:		 PL25*2200
#
# Ifc type:	 IfcPlate
# Guid:		 2Jbb7yhhDAo9E4mYtK3Hy_
# Name:		 brubjelke
# Description:	 PL16*5456
# Material:	 STEEL/S355NL
# Tag:	 ID9dbec873-288b-482c-b6ce-4d887920df56
# Type:		 PL16*5456
#
# Ifc type:	 IfcPlate
# Guid:		 0SrlCzfjH4CRLQD82u60Rq
# Name:		 brubjelke
# Description:	 PL30*3500
# Material:	 STEEL/S355NL
# Tag:	 IDc852c383-a1e8-4b4a-b15d-b9ebca451af7
# Type:		 PL30*3500
#
# Ifc type:	 IfcPlate
# Guid:		 3WJzeAxsb1IRGSLUbHCsHu
# Name:		 brubjelke
# Description:	 PL25*2200
# Material:	 STEEL/S355NL
# Tag:	 IDd6539ec9-6295-4aa9-a824-581bf9691399
# Type:		 PL25*2200
#
# Ifc type:	 IfcPlate
# Guid:		 083nx0bhzBA867l7XkeYNg
# Name:		 brubjelke
# Description:	 PL16*5456
# Material:	 STEEL/S355NL
# Tag:	 ID93e49e4e-5a87-42df-b553-b4d3732e8417
# Type:		 PL16*5456
#
# Ifc type:	 IfcPlate
# Guid:		 0x90muGrfDqe9KuM7gbyWj
# Name:		 brubjelke
# Description:	 PL30*3500
# Material:	 STEEL/S355NL
# Tag:	 ID9016e852-ffb7-4194-a210-5b26c29a86bb
# Type:		 PL30*3500
#
# Ifc type:	 IfcPlate
# Guid:		 2ifeOh66bEiQDgajBl5gSK
# Name:		 brubjelke
# Description:	 PL25*2200
# Material:	 STEEL/S355NL
# Tag:	 ID4de2836b-14b0-48a4-8af7-2a6c39f6b283
# Type:		 PL25*2200
#
# Ifc type:	 IfcPlate
# Guid:		 2gKZLOzE1DR931Jy$K0oU7
# Name:		 brubjelke
# Description:	 PL16*5456
# Material:	 STEEL/S355NL
# Tag:	 ID83474d8c-5deb-46e3-b20b-e43465e94214
# Type:		 PL16*5456
#
# Ifc type:	 IfcPlate
# Guid:		 3O3VVHfbjCEQLeSz9KY26X
# Name:		 brubjelke
# Description:	 PL30*3500
# Material:	 STEEL/S355NL
# Tag:	 ID1b6f6a21-8525-4f70-93d5-35405667dcd4
# Type:		 PL30*3500
#
# Ifc type:	 IfcPlate
# Guid:		 1f778inJzC0Ox3$C7kilgg
# Name:		 brubjelke
# Description:	 PL25*2200
# Material:	 STEEL/S355NL
# Tag:	 ID619852e6-d14d-4e1d-84e9-e3b87bc6d7d9
# Type:		 PL25*2200
#
# Ifc type:	 IfcPlate
# Guid:		 38t1YYSzPFvftqqZNrEU9r
# Name:		 brubjelke
# Description:	 PL16*5456
# Material:	 STEEL/S355NL
# Tag:	 ID5891d25f-af00-4bf0-b432-5b1e577a66dd
# Type:		 PL16*5456
#
# Ifc type:	 IfcPlate
# Guid:		 0qKlbMTGn6lP2$60xu6swh
# Name:		 brubjelke
# Description:	 PL30*3500
# Material:	 STEEL/S355NL
# Tag:	 IDf1ca020a-4fa7-46ae-a0a6-6a3f9b05ce9b
# Type:		 PL30*3500
#
# Ifc type:	 IfcPlate
# Guid:		 3WQCykswL9wP0iIzZJcp90
# Name:		 brubjelke
# Description:	 PL25*2200
# Material:	 STEEL/S355NL
# Tag:	 ID08829980-3eaa-4a1d-8395-0db28c189f18
# Type:		 PL25*2200
#
# Ifc type:	 IfcPlate
# Guid:		 1zE_7yGMDAteOxqD7UH4ix
# Name:		 brubjelke
# Description:	 PL16*5456
# Material:	 STEEL/S355NL
# Tag:	 IDdebe2abc-fb45-41f7-b101-f1087514de60
# Type:		 PL16*5456
#
# Ifc type:	 IfcPlate
# Guid:		 0zVEtNxKPCz9WtsM_6MSyG
# Name:		 brubjelke
# Description:	 PL30*3500
# Material:	 STEEL/S355NL
# Tag:	 ID09389991-e77f-479c-9c91-4eb65201ecc4
# Type:		 PL30*3500
#
# Ifc type:	 IfcPlate
# Guid:		 18qXx7OvzAseRcarHZL1vA
# Name:		 brubjelke
# Description:	 PL25*2200
# Material:	 STEEL/S355NL
# Tag:	 ID9d42c5dd-1bc2-435c-b795-fa24f48f81c0
# Type:		 PL25*2200
#
# Ifc type:	 IfcPlate
# Guid:		 2zkAaI93L4Ih1SnyK6g5uo
# Name:		 brubjelke
# Description:	 PL16*5456
# Material:	 STEEL/S355NL
# Tag:	 IDc6da1e29-393d-4105-a3a2-294ad53795c0
# Type:		 PL16*5456
#
# Ifc type:	 IfcPlate
# Guid:		 1tTQt8Ij9DQwTREm1tmYo1
# Name:		 brubjelke
# Description:	 PL30*3500
# Material:	 STEEL/S355NL
# Tag:	 ID42a8416e-249b-4bff-9aa2-ca486484b764
# Type:		 PL30*3500
#
# Ifc type:	 IfcPlate
# Guid:		 1GmcEBiEz7owXMHejWhLqG
# Name:		 brubjelke
# Description:	 PL25*2200
# Material:	 STEEL/S355NL
# Tag:	 ID74f4b49e-c68e-4d30-a967-78ae175debb6
# Type:		 PL25*2200
#
# Ifc type:	 IfcPlate
# Guid:		 1oIW$jGvnBPQzbOWIlQakE
# Name:		 brubjelke
# Description:	 PL16*5456
# Material:	 STEEL/S355NL
# Tag:	 ID64558d07-4e0a-4210-a085-2a07557ae1d3
# Type:		 PL16*5456
#
# Ifc type:	 IfcPlate
# Guid:		 2rukSD11rDTv_DRJYPNiGx
# Name:		 brubjelke
# Description:	 PL30*3500
# Material:	 STEEL/S355NL
# Tag:	 ID96a97d1f-8b12-480c-94dd-bb7a3c53e6e8
# Type:		 PL30*3500
#
# Ifc type:	 IfcPlate
# Guid:		 3aUuVkIWL468YaAwZ5nP7R
# Name:		 brubjelke
# Description:	 PL25*2200
# Material:	 STEEL/S355NL
# Tag:	 ID66ee7095-a22b-4aca-8061-c65c57c3f650
# Type:		 PL25*2200
#
# Ifc type:	 IfcPlate
# Guid:		 3NAR2Wq4b5IhfxwBgS9n3S
# Name:		 brubjelke
# Description:	 PL16*5456
# Material:	 STEEL/S355NL
# Tag:	 ID2644dce3-7d0c-45c8-b629-bdb346693b1b
# Type:		 PL16*5456
#
# Ifc type:	 IfcPlate
# Guid:		 1SK7BPHwD1hxF$Sz$9rwZo
# Name:		 brubjelke
# Description:	 PL30*3500
# Material:	 STEEL/S355NL
# Tag:	 ID537e705d-1268-482a-a20b-3285c7aedc91
# Type:		 PL30*3500
#
# Ifc type:	 IfcPlate
# Guid:		 14lJ_atYLCRAG12AlYWj4h
# Name:		 brubjelke
# Description:	 PL25*2200
# Material:	 STEEL/S355NL
# Tag:	 IDe387c250-dba7-4f9a-ad8c-437f70859680
# Type:		 PL25*2200
#
# Ifc type:	 IfcPlate
# Guid:		 1OyA6R6JT48RfpyiYK$7f3
# Name:		 brubjelke
# Description:	 PL16*5456
# Material:	 STEEL/S355NL
# Tag:	 IDb1de6cb0-f8ad-45e4-a639-505186ef24f3
# Type:		 PL16*5456
#
# Ifc type:	 IfcPlate
# Guid:		 3mpCC7zOn8dhstvAu8TCb_
# Name:		 brubjelke
# Description:	 PL25*2200
# Material:	 STEEL/S355NL
# Tag:	 ID4a608fca-c46f-415c-a4bd-4426419d29ad
# Type:		 PL25*2200
#
# Ifc type:	 IfcPlate
# Guid:		 3l4Vjlffr9_hgMT8u0wSZX
# Name:		 brubjelke
# Description:	 PL30*3500
# Material:	 STEEL/S355NL
# Tag:	 ID7fe28116-ddfc-4f12-823a-95d141dba128
# Type:		 PL30*3500
#
# Ifc type:	 IfcPlate
# Guid:		 0jmXCQz$X1Rg6o91F2rane
# Name:		 brubjelke
# Description:	 PL16*5456
# Material:	 STEEL/S355NL
# Tag:	 ID08cd07fd-ff35-4c3b-83f1-6ee95b3ace27
# Type:		 PL16*5456
#
# Ifc type:	 IfcPlate
# Guid:		 3dCRFPL19DtvleRvHO6_sH
# Name:		 brubjelke
# Description:	 PL30*3500
# Material:	 STEEL/S355NL
# Tag:	 ID373a4a75-f8b3-4910-acbc-d5a1c0197013
# Type:		 PL30*3500
#
# Ifc type:	 IfcPlate
# Guid:		 39tvpoNrL5o8A1cI_wBwky
# Name:		 brubjelke
# Description:	 PL25*2200
# Material:	 STEEL/S355NL
# Tag:	 ID1f881ff5-7e07-41ef-bb5e-2bfce90b066e
# Type:		 PL25*2200
#
# Ifc type:	 IfcPlate
# Guid:		 0H2$eXROb45RYQMPSQwgWj
# Name:		 brubjelke
# Description:	 PL16*5456
# Material:	 STEEL/S355NL
# Tag:	 ID58a0ebf2-2bdc-4327-9206-dfccb9796267
# Type:		 PL16*5456
#
# Ifc type:	 IfcPlate
# Guid:		 2wsMsGc9LFUPRlIQ$ITArf
# Name:		 brubjelke
# Description:	 PL30*3500
# Material:	 STEEL/S355NL
# Tag:	 ID34291e6d-d986-4673-8d0f-2134266c5749
# Type:		 PL30*3500
#
# Ifc type:	 IfcPlate
# Guid:		 0GLJsQV15Bwfn7s7XgLhtL
# Name:		 brubjelke
# Description:	 PL25*2200
# Material:	 STEEL/S355NL
# Tag:	 ID5e3b341a-24db-4210-bcf6-f5cc59e7f5e7
# Type:		 PL25*2200
#
# Ifc type:	 IfcPlate
# Guid:		 227go4KVz66QN9BtIbne2q
# Name:		 brubjelke
# Description:	 PL16*5456
# Material:	 STEEL/S355NL
# Tag:	 IDc5b0f878-7d1c-4c29-a9e9-0f9c810084ef
# Type:		 PL16*5456
#
# Ifc type:	 IfcPlate
# Guid:		 0tvuiWvFb6_B9FGL4xfDRT
# Name:		 brubjelke
# Description:	 PL30*3500
# Material:	 STEEL/S355NL
# Tag:	 IDa24ccd24-224f-4ee6-9b7e-e6d98c3396e2
# Type:		 PL30*3500
#
# Ifc type:	 IfcPlate
# Guid:		 0wmkHuUs192eG$kO3d$wL6
# Name:		 brubjelke
# Description:	 PL25*2200
# Material:	 STEEL/S355NL
# Tag:	 ID7c4f8161-3bc2-4e6e-a913-5bc0eb640f4d
# Type:		 PL25*2200
#
# Ifc type:	 IfcPlate
# Guid:		 0iaoePCPX7XAb3_rcnjco$
# Name:		 brubjelke
# Description:	 PL16*5456
# Material:	 STEEL/S355NL
# Tag:	 IDc1232e24-8bdf-4121-aa84-35ef517d7b67
# Type:		 PL16*5456
#
# Ifc type:	 IfcPlate
# Guid:		 2t7$Sh1UX4WgJdi3wwK487
# Name:		 brubjelke
# Description:	 PL30*3500
# Material:	 STEEL/S355NL
# Tag:	 IDca5a039f-acc6-4e77-b8a4-5d924efec125
# Type:		 PL30*3500
#
# Ifc type:	 IfcPlate
# Guid:		 2z2_LERh1FOO2idEd5njXq
# Name:		 brubjelke
# Description:	 PL25*2200
# Material:	 STEEL/S355NL
# Tag:	 ID5cd3bafb-10e5-43ef-a396-adeaa80982d7
# Type:		 PL25*2200
#
# Ifc type:	 IfcPlate
# Guid:		 3hV01UQx12MAF3W73gSVoM
# Name:		 brubjelke
# Description:	 PL16*5456
# Material:	 STEEL/S355NL
# Tag:	 IDf4ec4eee-c700-4326-94c1-bc2dedcea7d8
# Type:		 PL16*5456
#
# Ifc type:	 IfcPlate
# Guid:		 1EW55POWPAxP0DiliIjuzt
# Name:		 brubjelke
# Description:	 PL30*3500
# Material:	 STEEL/S355NL
# Tag:	 ID8afd8743-cb36-4753-b568-105c08aea8e0
# Type:		 PL30*3500
#
# Ifc type:	 IfcPlate
# Guid:		 1yMAOMZ55BdhqRtHjtQoxd
# Name:		 brubjelke
# Description:	 PL25*2200
# Material:	 STEEL/S355NL
# Tag:	 ID7c327840-c7b0-4d53-8b08-a82396446faf
# Type:		 PL25*2200
#
# Ifc type:	 IfcPlate
# Guid:		 3gLzPHKkv8xO_OHnT5VPyW
# Name:		 brubjelke
# Description:	 PL16*5456
# Material:	 STEEL/S355NL
# Tag:	 IDbb45c012-81fe-446f-9f5d-1349fdc2e964
# Type:		 PL16*5456
#
# Ifc type:	 IfcPlate
# Guid:		 3RbCuPEGT7$PoAZpTKjbW$
# Name:		 brubjelke
# Description:	 PL30*3500
# Material:	 STEEL/S355NL
# Tag:	 ID50ec36ab-d175-4fa5-8801-dd840429c673
# Type:		 PL30*3500
#
# Ifc type:	 IfcPlate
# Guid:		 1epFTPGBb3IRlBo9QH386k
# Name:		 brubjelke
# Description:	 PL25*2200
# Material:	 STEEL/S355NL
# Tag:	 ID58685cc3-edc3-424c-ad92-0289cdbbe40b
# Type:		 PL25*2200
#
# Ifc type:	 IfcPlate
# Guid:		 2tgqJppz9Dn8Q4GgatzkGA
# Name:		 brubjelke
# Description:	 PL16*5456
# Material:	 STEEL/S355NL
# Tag:	 ID0113fd89-627f-48a7-a5c5-e65bbd80e5c1
# Type:		 PL16*5456
#
# Ifc type:	 IfcPlate
# Guid:		 1t0dJQwKT1nw2SxQiiUVhc
# Name:		 brubjelke
# Description:	 PL30*3500
# Material:	 STEEL/S355NL
# Tag:	 ID0342283a-b8b5-4080-8e79-814dd3f36961
# Type:		 PL30*3500
#
# Ifc type:	 IfcPlate
# Guid:		 3YGQl68PX4yOEtg2pVfNq9
# Name:		 brubjelke
# Description:	 PL25*2200
# Material:	 STEEL/S355NL
# Tag:	 ID29659767-c61a-4367-9659-d0a258d5e72d
# Type:		 PL25*2200
#
# Ifc type:	 IfcPlate
# Guid:		 3iDgZCz7rEhhDYSTEk3CyZ
# Name:		 brubjelke
# Description:	 PL16*5456
# Material:	 STEEL/S355NL
# Tag:	 ID8caaaebd-0f54-4417-b3e5-b3fd4dc339d3
# Type:		 PL16*5456
#
# Ifc type:	 IfcPlate
# Guid:		 3AMQ2n8c53RxIBkUhaLj4Y
# Name:		 brubjelke
# Description:	 PL30*3500
# Material:	 STEEL/S355NL
# Tag:	 IDef701faf-9e84-4fc4-983a-7cc57095a300
# Type:		 PL30*3500
#
# Ifc type:	 IfcPlate
# Guid:		 1IwDmAbA13_QHprpuG4g5K
# Name:		 brubjelke
# Description:	 PL25*2200
# Material:	 STEEL/S355NL
# Tag:	 ID97a932a1-3e56-4e27-a319-f5c2459488f8
# Type:		 PL25*2200
#
# Ifc type:	 IfcPlate
# Guid:		 3XnwAwtDv2j8EJkQjV$ibU
# Name:		 brubjelke
# Description:	 PL16*5456
# Material:	 STEEL/S355NL
# Tag:	 IDf9ebe74b-8461-45ec-97b7-6e99ba94440f
# Type:		 PL16*5456
#
# Ifc type:	 IfcPlate
# Guid:		 0aRYc1B$v6lxNK23SR45W8
# Name:		 brubjelke
# Description:	 PL30*3500
# Material:	 STEEL/S355NL
# Tag:	 IDd3d93ae7-4d24-4adf-b956-cc37ca3c30f8
# Type:		 PL30*3500
#
# Ifc type:	 IfcPlate
# Guid:		 2D23ad$7L2ygud8V$qdE7B
# Name:		 brubjelke
# Description:	 PL25*2200
# Material:	 STEEL/S355NL
# Tag:	 ID9a0fc70c-5a4e-4f0c-932d-f097a9692a85
# Type:		 PL25*2200
#
# Ifc type:	 IfcPlate
# Guid:		 2HOeJr_aD7RRAU0uRRAPKs
# Name:		 brubjelke
# Description:	 PL16*5456
# Material:	 STEEL/S355NL
# Tag:	 ID3504471c-069f-4237-8675-e88059c0f453
# Type:		 PL16*5456
#
# Ifc type:	 IfcPlate
# Guid:		 3RNN0tLwn48eYrBNEXWAvi
# Name:		 brubjelke
# Description:	 PL30*3500
# Material:	 STEEL/S355NL
# Tag:	 ID884e78ee-52fc-4d74-9010-ac8d94d15626
# Type:		 PL30*3500
#
# Ifc type:	 IfcPlate
# Guid:		 29lisqXr53PvaVV_0dQk7S
# Name:		 brubjelke
# Description:	 PL25*2200
# Material:	 STEEL/S355NL
# Tag:	 ID18db7c97-6b36-4b38-881c-54f4d9380c4a
# Type:		 PL25*2200
#
# Ifc type:	 IfcPlate
# Guid:		 3nRNPoqKb8dhNd_914eMX7
# Name:		 brubjelke
# Description:	 PL16*5456
# Material:	 STEEL/S355NL
# Tag:	 ID9428f1ac-3155-4ab0-b78e-051036d460e7
# Type:		 PL16*5456
#
# Ifc type:	 IfcPlate
# Guid:		 33jP2cM0PAyQx4j43il8kB
# Name:		 brubjelke
# Description:	 PL30*3500
# Material:	 STEEL/S355NL
# Tag:	 IDe37da476-fd98-4295-82e4-71ccb9d4303a
# Type:		 PL30*3500
#
# Ifc type:	 IfcPlate
# Guid:		 1CuJuC6S9EOeqOldaGrtMd
# Name:		 brubjelke
# Description:	 PL25*2200
# Material:	 STEEL/S355NL
# Tag:	 ID77340566-5be8-451c-bf77-24c669bb2aa0
# Type:		 PL25*2200
#
# Ifc type:	 IfcPlate
# Guid:		 30vL63dgDFNwdL75R3MD_q
# Name:		 brubjelke
# Description:	 PL16*5456
# Material:	 STEEL/S355NL
# Tag:	 ID6b31bd6e-4c16-400a-b04a-ed26ffd16d20
# Type:		 PL16*5456
#
# Ifc type:	 IfcPlate
# Guid:		 0Gec8TTSL7t9xszPF5bIb1
# Name:		 brubjelke
# Description:	 PL25*2200
# Material:	 STEEL/S355NL
# Tag:	 IDe02ed35e-cf0a-45f2-b97e-10e27c7c5755
# Type:		 PL25*2200
#
# Ifc type:	 IfcPlate
# Guid:		 30y85f_ofAjQzStM$RrJgq
# Name:		 brubjelke
# Description:	 PL30*3500
# Material:	 STEEL/S355NL
# Tag:	 IDe6466f8f-b85a-4e23-a795-92c03849b3a0
# Type:		 PL30*3500
#
# Ifc type:	 IfcPlate
# Guid:		 1i4DM$bR57tv4uqh098bsz
# Name:		 brubjelke
# Description:	 PL16*5456
# Material:	 STEEL/S355NL
# Tag:	 ID6e5d281d-5a1b-4799-8deb-c90cd7f600ee
# Type:		 PL16*5456
#
# Ifc type:	 IfcPlate
# Guid:		 23avaLIs94IOe4Vz2vEXQv
# Name:		 brubjelke
# Description:	 PL25*2200
# Material:	 STEEL/S355NL
# Tag:	 IDc0d154c5-0f4b-4899-a7fd-1eff5edea1d0
# Type:		 PL25*2200
#
# Ifc type:	 IfcPlate
# Guid:		 0pwHYTJnT7OwdWtAWY2Xlf
# Name:		 brubjelke
# Description:	 PL30*3500
# Material:	 STEEL/S355NL
# Tag:	 IDe8e9a3e3-8dc4-42c7-8963-ed101037757f
# Type:		 PL30*3500
#
# Ifc type:	 IfcPlate
# Guid:		 0Xmoneyn58Le$yA4nPAYPu
# Name:		 brubjelke
# Description:	 PL16*5456
# Material:	 STEEL/S355NL
# Tag:	 IDe4484e64-eee4-4414-9215-1e6bb1469b9b
# Type:		 PL16*5456
#
# Ifc type:	 IfcPlate
# Guid:		 0mCJqX2tDEXvTgndWHGY0W
# Name:		 brubjelke
# Description:	 PL25*2200
# Material:	 STEEL/S355NL
# Tag:	 ID57b3b39b-d280-4d5e-bd7d-bf30ddd6cb53
# Type:		 PL25*2200
#
# Ifc type:	 IfcPlate
# Guid:		 2MGZuV5RLF2Q9qtd71q0RR
# Name:		 brubjelke
# Description:	 PL30*3500
# Material:	 STEEL/S355NL
# Tag:	 ID0e7caea0-14d8-42dc-b664-cfbfc2c30f93
# Type:		 PL30*3500
#
# Ifc type:	 IfcPlate
# Guid:		 1WXkBZ1b59UgrenqLTjAr_
# Name:		 brubjelke
# Description:	 PL16*5456
# Material:	 STEEL/S355NL
# Tag:	 ID28d179b2-66cd-4af5-9de1-6ce585e975a1
# Type:		 PL16*5456
#
# Ifc type:	 IfcPlate
# Guid:		 3A1hwvxr95sRd4Lw7tG3L4
# Name:		 brubjelke
# Description:	 PL25*2200
# Material:	 STEEL/S355NL
# Tag:	 ID540ea594-0f0f-4742-bd24-b8e55b72ead0
# Type:		 PL25*2200
#
# Ifc type:	 IfcPlate
# Guid:		 2cixlTalP3iP08PpZV4ID$
# Name:		 brubjelke
# Description:	 PL30*3500
# Material:	 STEEL/S355NL
# Tag:	 IDbbe7cffd-d68b-43f2-9fde-13359c4d508c
# Type:		 PL30*3500
#
# Ifc type:	 IfcPlate
# Guid:		 0zp13fWQnDX8t7ftiuiwnL
# Name:		 brubjelke
# Description:	 PL16*5456
# Material:	 STEEL/S355NL
# Tag:	 ID6265d3bc-c6aa-403f-bed7-4b2f09903d19
# Type:		 PL16*5456
#
# Ifc type:	 IfcPlate
# Guid:		 0pmPQMD697AQzmgX6vZR65
# Name:		 brubjelke
# Description:	 PL25*2200
# Material:	 STEEL/S355NL
# Tag:	 IDaa409644-7597-4614-a658-bb9822fe1188
# Type:		 PL25*2200
#
# Ifc type:	 IfcPlate
# Guid:		 0xQdbXbNT0geS3INsOAIv1
# Name:		 brubjelke
# Description:	 PL30*3500
# Material:	 STEEL/S355NL
# Tag:	 ID2b8af88b-d785-4a9e-9b19-cb1c4fc5c04d
# Type:		 PL30*3500
#
# Ifc type:	 IfcPlate
# Guid:		 0lgBJDz4n8r8YuG40RIwQT
# Name:		 brubjelke
# Description:	 PL16*5456
# Material:	 STEEL/S355NL
# Tag:	 ID22fbf9c8-3506-454c-b6ff-4c4a16403611
# Type:		 PL16*5456
#
# Ifc type:	 IfcPlate
# Guid:		 2wsdz2MEzFOO0ke4nhFIU6
# Name:		 brubjelke
# Description:	 PL25*2200
# Material:	 STEEL/S355NL
# Tag:	 ID537edbce-5596-4539-a9f2-3bbe49d905e4
# Type:		 PL25*2200
#
# Ifc type:	 IfcPlate
# Guid:		 0R2pvgxyL5gA0FknAnfjyZ
# Name:		 brubjelke
# Description:	 PL30*3500
# Material:	 STEEL/S355NL
# Tag:	 ID9927b949-3e4c-4480-9c1f-4d35ca62d120
# Type:		 PL30*3500
#
# Ifc type:	 IfcPlate
# Guid:		 3Jj0N0f3j0dQ2MySMrj1ss
# Name:		 brubjelke
# Description:	 PL16*5456
# Material:	 STEEL/S355NL
# Tag:	 ID07a63698-c421-406e-87dd-be7fb1ef2e49
# Type:		 PL16*5456
#
# Ifc type:	 IfcPlate
# Guid:		 2OPPFXHDr3iem9KdXwecpH
# Name:		 brubjelke
# Description:	 PL25*2200
# Material:	 STEEL/S355NL
# Tag:	 IDa900bbeb-e9da-4e71-aef5-48c96ecb0a11
# Type:		 PL25*2200
#
# Ifc type:	 IfcPlate
# Guid:		 01vKVH22L9EONuV65Y1SPp
# Name:		 brubjelke
# Description:	 PL30*3500
# Material:	 STEEL/S355NL
# Tag:	 ID7ec2b839-12d6-4547-bc0f-2b33c6970d2c
# Type:		 PL30*3500
#
# Ifc type:	 IfcPlate
# Guid:		 0cCxOopMT45xfj3nmdHL7o
# Name:		 brubjelke
# Description:	 PL25*2200
# Material:	 STEEL/S355NL
# Tag:	 ID7286555c-93d9-4c14-8593-afad94348978
# Type:		 PL25*2200
#
# Ifc type:	 IfcPlate
# Guid:		 1lqzo5RBv6nezrkINuPza7
# Name:		 brubjelke
# Description:	 PL16*5456
# Material:	 STEEL/S355NL
# Tag:	 ID2b204e41-6393-4246-a98d-d90a7bdb1ef8
# Type:		 PL16*5456
#
# Ifc type:	 IfcPlate
# Guid:		 2NgOeszfL12RFa3iIXILoo
# Name:		 brubjelke
# Description:	 PL30*3500
# Material:	 STEEL/S355NL
# Tag:	 IDf829d50b-474c-49b6-8a10-9a6f6a7f9c2d
# Type:		 PL30*3500
#
# Ifc type:	 IfcPlate
# Guid:		 3yVbXTqHf6lf$hcssmkPMm
# Name:		 brubjelke
# Description:	 PL25*2200
# Material:	 STEEL/S355NL
# Tag:	 IDe38ba098-8cec-45e6-ac2a-0b02a9a9d82b
# Type:		 PL25*2200
#
# Ifc type:	 IfcPlate
# Guid:		 1mwE3RosfChwcOkPqYG4xr
# Name:		 brubjelke
# Description:	 PL16*5456
# Material:	 STEEL/S355NL
# Tag:	 ID3dfe7f2f-77cc-4356-a18c-65fc0f833d61
# Type:		 PL16*5456
#
# Ifc type:	 IfcPlate
# Guid:		 08gLKdYa15_82CEP7NjWiL
# Name:		 brubjelke
# Description:	 PL30*3500
# Material:	 STEEL/S355NL
# Tag:	 ID27a0e89e-9140-41df-847e-607b0c613f33
# Type:		 PL30*3500
#
# Ifc type:	 IfcPlate
# Guid:		 06BaDP8Hf7Y9Vws7uTPkHz
# Name:		 brubjelke
# Description:	 PL16*5456
# Material:	 STEEL/S355NL
# Tag:	 IDb3e2feb6-4415-4d0c-b004-42afa35f688d
# Type:		 PL16*5456
#
# Ifc type:	 IfcPlate
# Guid:		 2XHF0PGX90Du$EiwMVG9Yk
# Name:		 brubjelke
# Description:	 PL30*3500
# Material:	 STEEL/S355NL
# Tag:	 ID429488c9-d50f-48de-b569-8c366c3128ce
# Type:		 PL30*3500
#
# Ifc type:	 IfcPlate
# Guid:		 1r8IdcRL1Bfexw2QMWWhu4
# Name:		 brubjelke
# Description:	 PL25*2200
# Material:	 STEEL/S355NL
# Tag:	 ID72883dbc-b46c-4a30-bb93-884cbf02b37d
# Type:		 PL25*2200
#
# Ifc type:	 IfcPlate
# Guid:		 0fDy$zgKf5fB4LM$R1cDR7
# Name:		 brubjelke
# Description:	 PL16*5456
# Material:	 STEEL/S355NL
# Tag:	 ID3813a465-7d0c-4d08-bd62-2fcde1b4d967
# Type:		 PL16*5456
#
# Ifc type:	 IfcPlate
# Guid:		 35CgPBG51BxeIGhiuLVEx6
# Name:		 brubjelke
# Description:	 PL30*3500
# Material:	 STEEL/S355NL
# Tag:	 ID7ececb3e-ce71-4158-ba4b-877cf9b9818c
# Type:		 PL30*3500
#
# Ifc type:	 IfcPlate
# Guid:		 1x4yBzdQb1eOZtkk9v1XVN
# Name:		 brubjelke
# Description:	 PL25*2200
# Material:	 STEEL/S355NL
# Tag:	 IDf443eb5a-fde3-41e8-8d89-54e5858cc8d1
# Type:		 PL25*2200
#
# Ifc type:	 IfcPlate
# Guid:		 3GtWPlxE5FsvAuEZ1hMbiM
# Name:		 brubjelke
# Description:	 PL16*5456
# Material:	 STEEL/S355NL
# Tag:	 ID1b39b51b-9375-455d-90bf-8ea9664be4ce
# Type:		 PL16*5456
#
# Ifc type:	 IfcPlate
# Guid:		 1GnVminAL7Av0aecjMyCK$
# Name:		 brubjelke
# Description:	 PL30*3500
# Material:	 STEEL/S355NL
# Tag:	 ID6ff9814f-0c28-43ad-8c88-0703949f61d9
# Type:		 PL30*3500
#
# Ifc type:	 IfcPlate
# Guid:		 3NU31EEJD1JRdiBdTFtt$W
# Name:		 brubjelke
# Description:	 PL25*2200
# Material:	 STEEL/S355NL
# Tag:	 ID26754a30-4897-4bac-8e1a-d9e277ea44b4
# Type:		 PL25*2200
#
# Ifc type:	 IfcPlate
# Guid:		 0sbDcqAIz54hvopvuuAF1c
# Name:		 brubjelke
# Description:	 PL16*5456
# Material:	 STEEL/S355NL
# Tag:	 ID549484f6-aafd-429b-bd5a-34839a2a090a
# Type:		 PL16*5456
#
# Ifc type:	 IfcPlate
# Guid:		 1t6KqvKd56QRlUc9XWj$OR
# Name:		 brubjelke
# Description:	 PL30*3500
# Material:	 STEEL/S355NL
# Tag:	 IDa562674e-8df2-4321-9816-21bfd26cd19f
# Type:		 PL30*3500
#
# Ifc type:	 IfcPlate
# Guid:		 1RDMsfgOr2COfPAfqCO0XU
# Name:		 brubjelke
# Description:	 PL25*2200
# Material:	 STEEL/S355NL
# Tag:	 ID8b03f152-9846-49d2-b42a-533c12b2c391
# Type:		 PL25*2200
#
# Ifc type:	 IfcPlate
# Guid:		 0qnNWus4LFE94N2TxZLBoA
# Name:		 brubjelke
# Description:	 PL25*2200
# Material:	 STEEL/S355NL
# Tag:	 IDe9ab955a-a69f-43fd-af83-8195750418a9
# Type:		 PL25*2200
#
# Ifc type:	 IfcPlate
# Guid:		 0Z6nmQO7DArf53nHOue1pp
# Name:		 brubjelke
# Description:	 PL16*5456
# Material:	 STEEL/S355NL
# Tag:	 ID99fb7b19-d96d-433c-9e5a-45620db3143e
# Type:		 PL16*5456
#
# Ifc type:	 IfcPlate
# Guid:		 08kX9uH81Fsug4Bt9dCVYs
# Name:		 brubjelke
# Description:	 PL30*3500
# Material:	 STEEL/S355NL
# Tag:	 ID0639800c-1627-4163-a57b-5841ebd564bd
# Type:		 PL30*3500
#
# Ifc type:	 IfcPlate
# Guid:		 1xcvO77bjEIALthoftoPeq
# Name:		 brubjelke
# Description:	 PL25*2200
# Material:	 STEEL/S355NL
# Tag:	 IDb64bc24a-4322-4c4b-9d5f-dba6f08f4934
# Type:		 PL25*2200
#
# Ifc type:	 IfcPlate
# Guid:		 3$Mfu1lW51ofUQ1RLNI25J
# Name:		 brubjelke
# Description:	 PL16*5456
# Material:	 STEEL/S355NL
# Tag:	 ID775985c9-f0ad-4f70-9157-78e52fa010fe
# Type:		 PL16*5456
#
# Ifc type:	 IfcPlate
# Guid:		 36MQYP7kv3pfx2wWUYkECE
# Name:		 brubjelke
# Description:	 PL30*3500
# Material:	 STEEL/S355NL
# Tag:	 ID9a1d8ecf-8ee1-4662-b1c3-f3c27fc8510c
# Type:		 PL30*3500
#
# Ifc type:	 IfcPlate
# Guid:		 3AxlsvgUbE9hxtC8z2M7ce
# Name:		 brubjelke
# Description:	 PL25*2200
# Material:	 STEEL/S355NL
# Tag:	 IDd60979b6-f0be-41ba-8097-33998d128adb
# Type:		 PL25*2200
#
# Ifc type:	 IfcPlate
# Guid:		 2DgxYLJY15$gr_YZP5qVDZ
# Name:		 brubjelke
# Description:	 PL30*3500
# Material:	 STEEL/S355NL
# Tag:	 ID67becf0e-cd78-4736-87b2-f1d5fcd368f7
# Type:		 PL30*3500
#
# Ifc type:	 IfcPlate
# Guid:		 2ns9_Fw5n1yv5RKvSqaLQq
# Name:		 brubjelke
# Description:	 PL16*5456
# Material:	 STEEL/S355NL
# Tag:	 ID6a5f672c-0bc7-4cac-8828-4caa69ab81e2
# Type:		 PL16*5456
#
# Ifc type:	 IfcPlate
# Guid:		 0smgdnI95DV9WSn6aYArpw
# Name:		 brubjelke
# Description:	 PL25*2200
# Material:	 STEEL/S355NL
# Tag:	 IDaa41c861-9ff9-423c-9de4-743f08299847
# Type:		 PL25*2200
#
# Ifc type:	 IfcPlate
# Guid:		 1pjXw7_hnEZR9vu6FJJIyN
# Name:		 brubjelke
# Description:	 PL30*3500
# Material:	 STEEL/S355NL
# Tag:	 ID6f59a484-d411-42b1-94f8-1e27998d9c41
# Type:		 PL30*3500
#
# Ifc type:	 IfcPlate
# Guid:		 0osHajz$rCggbI2$WWrlky
# Name:		 brubjelke
# Description:	 PL16*5456
# Material:	 STEEL/S355NL
# Tag:	 ID07f4c7c6-3cab-4318-8095-a385fa43b00d
# Type:		 PL16*5456
#
# Ifc type:	 IfcPlate
# Guid:		 0I1o8t0qf8nBNDyDTlPD3n
# Name:		 brubjelke
# Description:	 PL25*2200
# Material:	 STEEL/S355NL
# Tag:	 IDe84a1892-86c4-473c-b425-09ed8f38d07a
# Type:		 PL25*2200
#
# Ifc type:	 IfcPlate
# Guid:		 2usbmWdkH6tfjZnnZsr5$C
# Name:		 brubjelke
# Description:	 PL30*3500
# Material:	 STEEL/S355NL
# Tag:	 IDcc1146c0-fa77-4a48-b945-383ecc505077
# Type:		 PL30*3500
#
# Ifc type:	 IfcPlate
# Guid:		 2xijdz0OX5DR2ejdY35QRE
# Name:		 brubjelke
# Description:	 PL16*5456
# Material:	 STEEL/S355NL
# Tag:	 ID09e72a45-3bbe-40e5-8c31-c49ad7a410a6
# Type:		 PL16*5456
#
# Ifc type:	 IfcPlate
# Guid:		 2IZiyxxZ9A$AG9ilgpZAy0
# Name:		 brubjelke
# Description:	 PL25*2200
# Material:	 STEEL/S355NL
# Tag:	 IDc9a0fac9-e6df-440e-89f7-bac9d4f456af
# Type:		 PL25*2200
#
# Ifc type:	 IfcPlate
# Guid:		 30Pl_R8Er5Y901u3k2Y5GI
# Name:		 brubjelke
# Description:	 PL30*3500
# Material:	 STEEL/S355NL
# Tag:	 IDbe96a826-74d5-4ded-b4bd-81f45958d643
# Type:		 PL30*3500
#
# Ifc type:	 IfcPlate
# Guid:		 28xHlAbzL0KRJFTMJ$Z31f
# Name:		 brubjelke
# Description:	 PL16*5456
# Material:	 STEEL/S355NL
# Tag:	 IDc4b5b9a7-2d0f-45c7-b13c-c268570da7c4
# Type:		 PL16*5456
#
# Ifc type:	 IfcPlate
# Guid:		 0XsD1UkX1Edull_KpxfwBM
# Name:		 brubjelke
# Description:	 PL25*2200
# Material:	 STEEL/S355NL
# Tag:	 ID18db0f78-c98f-4b50-8ff5-8991df79c7b7
# Type:		 PL25*2200
#
# Ifc type:	 IfcPlate
# Guid:		 37CrCNm3b8UeMYrNzjlfdC
# Name:		 brubjelke
# Description:	 PL30*3500
# Material:	 STEEL/S355NL
# Tag:	 ID002e9974-e558-4004-ad91-1155fb6c3dbb
# Type:		 PL30*3500
#
# Ifc type:	 IfcPlate
# Guid:		 3bXZA5WhD8_fubauzbtbKn
# Name:		 brubjelke
# Description:	 PL16*5456
# Material:	 STEEL/S355NL
# Tag:	 ID11be6fda-c504-4838-b48b-1f0493efe7e9
# Type:		 PL16*5456
#
# Ifc type:	 IfcPlate
# Guid:		 0XkN1l8e9DDh7kaEmzlLHd
# Name:		 brubjelke
# Description:	 PL30*3500
# Material:	 STEEL/S355NL
# Tag:	 ID43dfcd43-9920-404c-8cb0-f18105a4b1b1
# Type:		 PL30*3500
#
# Ifc type:	 IfcPlate
# Guid:		 0H0cK8QP5CJfpSylThxiko
# Name:		 brubjelke
# Description:	 PL25*2200
# Material:	 STEEL/S355NL
# Tag:	 ID0ad82908-9aa8-4774-ab79-c0fcb24ff969
# Type:		 PL25*2200
#
# Ifc type:	 IfcPlate
# Guid:		 10uhmWymD5LBT5l3AG08t4
# Name:		 brubjelke
# Description:	 PL16*5456
# Material:	 STEEL/S355NL
# Tag:	 ID97deaf16-5e56-4050-8ad5-63ffad476b1c
# Type:		 PL16*5456
#
# Ifc type:	 IfcPlate
# Guid:		 1GXxx5dBn1cPGJJvrBhwDs
# Name:		 brubjelke
# Description:	 PL30*3500
# Material:	 STEEL/S355NL
# Tag:	 ID2a9e50ad-8e95-442b-aa2d-a7596e7bb927
# Type:		 PL30*3500
#
# Ifc type:	 IfcPlate
# Guid:		 0fGSpYcVL0awRiXtXBseQz
# Name:		 brubjelke
# Description:	 PL25*2200
# Material:	 STEEL/S355NL
# Tag:	 ID81f86f7e-aba5-416b-a64d-717dade47350
# Type:		 PL25*2200
#
# Ifc type:	 IfcPlate
# Guid:		 2APDIS_ff0FPq9Zj1ZQtqb
# Name:		 brubjelke
# Description:	 PL30*3500
# Material:	 STEEL/S355NL
# Tag:	 ID34ec5f5d-8af7-4ec3-8d68-90d32a3bd3fc
# Type:		 PL30*3500
#
# Ifc type:	 IfcPlate
# Guid:		 0ScKo5_3DBdB5FpFBVSgMG
# Name:		 brubjelke
# Description:	 PL16*5456
# Material:	 STEEL/S355NL
# Tag:	 IDab6bdddf-97c9-452e-8b04-cd5717525cbd
# Type:		 PL16*5456
#
# Ifc type:	 IfcPlate
# Guid:		 1KzL_8s319sB8fB0sHD$uu
# Name:		 brubjelke
# Description:	 PL25*2200
# Material:	 STEEL/S355NL
# Tag:	 ID1827cc9c-5e93-4703-ab5c-4bbba7ba6b75
# Type:		 PL25*2200
#
# Ifc type:	 IfcPlate
# Guid:		 0sh5Hg5Q59kPqKdR9NYifK
# Name:		 brubjelke
# Description:	 PL30*3500
# Material:	 STEEL/S355NL
# Tag:	 ID498f8f2c-4177-40c2-8faa-0f5d6173bbdc
# Type:		 PL30*3500
#
# Ifc type:	 IfcPlate
# Guid:		 1dpTC8_PHDChVJNDOV7BTe
# Name:		 brubjelke
# Description:	 PL16*5456
# Material:	 STEEL/S355NL
# Tag:	 ID89eeeb86-9fca-430d-ad9c-9e596110cf58
# Type:		 PL16*5456
#
# Ifc type:	 IfcPlate
# Guid:		 1K1Bdj2yr3Z9W2n9zMKO3x
# Name:		 brubjelke
# Description:	 PL30*3500
# Material:	 STEEL/S355NL
# Tag:	 ID7af3a255-a20a-4406-ad3f-a61ac334fe66
# Type:		 PL30*3500
#
# Ifc type:	 IfcPlate
# Guid:		 2nEva9ol14hPARSyoaMq5h
# Name:		 brubjelke
# Description:	 PL25*2200
# Material:	 STEEL/S355NL
# Tag:	 ID1544e5e7-cc72-4b0a-8576-0f8bf4bc81bb
# Type:		 PL25*2200
#
# Ifc type:	 IfcPlate
# Guid:		 2FIPO90753vxBKK80lxndn
# Name:		 brubjelke
# Description:	 PL16*5456
# Material:	 STEEL/S355NL
# Tag:	 ID144b1ff0-5e9b-4f33-a36c-2a509e16f568
# Type:		 PL16*5456
#
# Ifc type:	 IfcPlate
# Guid:		 057hN2YuD9yeZpQobHcsDM
# Name:		 brubjelke
# Description:	 PL30*3500
# Material:	 STEEL/S355NL
# Tag:	 ID6b9fbedf-a405-48a1-bbcb-674a8e114528
# Type:		 PL30*3500
#
# Ifc type:	 IfcPlate
# Guid:		 0SNRMS3PT10ukRfuNy3Mbv
# Name:		 brubjelke
# Description:	 PL25*2200
# Material:	 STEEL/S355NL
# Tag:	 IDd335f3ac-ee98-4a5e-88d1-36777d94c621
# Type:		 PL25*2200
#
# Ifc type:	 IfcPlate
# Guid:		 3e9ZKyDbX0z9mUGBeN9ZAH
# Name:		 brubjelke
# Description:	 PL16*5456
# Material:	 STEEL/S355NL
# Tag:	 ID418188e8-14b4-44a7-a006-63ee58ed6af9
# Type:		 PL16*5456
#
# Ifc type:	 IfcPlate
# Guid:		 0P7oNfhH1EOfolX7BFhHZW
# Name:		 brubjelke
# Description:	 PL30*3500
# Material:	 STEEL/S355NL
# Tag:	 IDbb0959d4-ecc3-48f4-a8bc-01f630c6703d
# Type:		 PL30*3500
#
# Ifc type:	 IfcPlate
# Guid:		 11YojuJ8L4MuHhquQceAVK
# Name:		 brubjelke
# Description:	 PL25*2200
# Material:	 STEEL/S355NL
# Tag:	 ID7bc182cf-77db-41d6-8fc7-9e495aa23b21
# Type:		 PL25*2200
#
# Ifc type:	 IfcPlate
# Guid:		 0AnFsdmZ53hxYirOmWL8DC
# Name:		 brubjelke
# Description:	 PL16*5456
# Material:	 STEEL/S355NL
# Tag:	 IDc2a78efd-aa82-4c72-84fa-e5a847914432
# Type:		 PL16*5456
#
# Ifc type:	 IfcPlate
# Guid:		 3yDAonRW19mgAvy6reESho
# Name:		 brubjelke
# Description:	 PL30*3500
# Material:	 STEEL/S355NL
# Tag:	 ID72985a4d-67ca-410c-81bc-e38af1812d85
# Type:		 PL30*3500
#
# Ifc type:	 IfcPlate
# Guid:		 3WTF9Gtpz9KhwCRhMf$q2C
# Name:		 brubjelke
# Description:	 PL25*2200
# Material:	 STEEL/S355NL
# Tag:	 ID98221663-6178-49fd-b7d4-428d3e55d7d5
# Type:		 PL25*2200
#
# Ifc type:	 IfcPlate
# Guid:		 1J_ASal4v55BCjCx0sn5n1
# Name:		 brubjelke
# Description:	 PL16*5456
# Material:	 STEEL/S355NL
# Tag:	 ID34727d1a-9e4f-4a06-8af9-16311db29220
# Type:		 PL16*5456
#
# Ifc type:	 IfcPlate
# Guid:		 1pZ13f3V9FfQg2EWr676bJ
# Name:		 brubjelke
# Description:	 PL30*3500
# Material:	 STEEL/S355NL
# Tag:	 ID7a0cd8ed-5787-40de-b601-ead47efbaaa8
# Type:		 PL30*3500
#
# Ifc type:	 IfcPlate
# Guid:		 1b4mrTwF5D99bPzN8PswIz
# Name:		 brubjelke
# Description:	 PL25*2200
# Material:	 STEEL/S355NL
# Tag:	 ID502c164e-e998-4988-8470-4cdbe5604465
# Type:		 PL25*2200
#
# Ifc type:	 IfcPlate
# Guid:		 0vXF8RlGv1HQIL4hvfoWqF
# Name:		 brubjelke
# Description:	 PL16*5456
# Material:	 STEEL/S355NL
# Tag:	 ID33490436-e0a1-4590-ab58-856d5d0fbd4c
# Type:		 PL16*5456
#
# Ifc type:	 IfcPlate
# Guid:		 00jvlywC9FQvRX2fCrccc9
# Name:		 brubjelke
# Description:	 PL30*3500
# Material:	 STEEL/S355NL
# Tag:	 ID42755913-522b-4726-af98-4cfa7b533a55
# Type:		 PL30*3500
#
# Ifc type:	 IfcPlate
# Guid:		 33j2JYNpr6BgHzu0q$rHiN
# Name:		 brubjelke
# Description:	 PL25*2200
# Material:	 STEEL/S355NL
# Tag:	 IDe19be734-0ccc-4e96-bc9f-b017ff2bb99c
# Type:		 PL25*2200
#
# Ifc type:	 IfcPlate
# Guid:		 3asLCct6nAmBCrErVnL0SO
# Name:		 brubjelke
# Description:	 PL16*5456
# Material:	 STEEL/S355NL
# Tag:	 ID28d1a123-0b59-4ba9-93a0-1870d9d3a39f
# Type:		 PL16*5456
#
# Ifc type:	 IfcPlate
# Guid:		 2aI1NXNwXDF8I13eEaUTij
# Name:		 brubjelke
# Description:	 PL30*3500
# Material:	 STEEL/S355NL
# Tag:	 ID4a90c24e-4498-4548-8af8-e5c6a75ff52b
# Type:		 PL30*3500
#
# Ifc type:	 IfcPlate
# Guid:		 0zAVvYsg91sOGu1kmyCn8T
# Name:		 brubjelke
# Description:	 PL25*2200
# Material:	 STEEL/S355NL
# Tag:	 ID32a1d587-3686-42ff-8e63-5fbdeb651fd2
# Type:		 PL25*2200
#
# Ifc type:	 IfcPlate
# Guid:		 0tcTt9IAbAE9$VeLt2rB_K
# Name:		 brubjelke
# Description:	 PL16*5456
# Material:	 STEEL/S355NL
# Tag:	 ID50974c87-0c65-4c46-bf5d-ba4302c45c99
# Type:		 PL16*5456
#
# Ifc type:	 IfcPlate
# Guid:		 0SXXFb97j4GB5RN97wLcGY
# Name:		 brubjelke
# Description:	 PL30*3500
# Material:	 STEEL/S355NL
# Tag:	 IDf0ab82b9-dab7-4922-b4ad-a917bb0e9caf
# Type:		 PL30*3500
#
# Ifc type:	 IfcPlate
# Guid:		 3u$rYJpcn5AhsijqO0Y0hw
# Name:		 brubjelke
# Description:	 PL25*2200
# Material:	 STEEL/S355NL
# Tag:	 IDc2b3f93b-f200-4ffc-b042-191eb4eee44f
# Type:		 PL25*2200
#
# Ifc type:	 IfcPlate
# Guid:		 06S0ksOfv13PDVpkyCtYxI
# Name:		 brubjelke
# Description:	 PL16*5456
# Material:	 STEEL/S355NL
# Tag:	 ID2d341071-e4a0-4b82-99c5-fee95ec0ce7f
# Type:		 PL16*5456
#
# Ifc type:	 IfcPlate
# Guid:		 0K9OPoTN14_wc15Nklc0rM
# Name:		 brubjelke
# Description:	 PL30*3500
# Material:	 STEEL/S355NL
# Tag:	 ID7c6d3c29-b31e-4267-aa9e-d229b68e40d8
# Type:		 PL30*3500
#
# Ifc type:	 IfcPlate
# Guid:		 1XkjQQD$H4yeDIaszA9CVu
# Name:		 brubjelke
# Description:	 PL25*2200
# Material:	 STEEL/S355NL
# Tag:	 IDb2861fcc-c7c9-4e48-be80-8dfd679721d9
# Type:		 PL25*2200
#
# Ifc type:	 IfcPlate
# Guid:		 36_9JImBn1IOKMgTImyIQP
# Name:		 brubjelke
# Description:	 PL16*5456
# Material:	 STEEL/S355NL
# Tag:	 ID7a0ffc28-b99e-4f88-9179-06a4039cbfc7
# Type:		 PL16*5456
#
# Ifc type:	 IfcPlate
# Guid:		 3XtbbE0GP2hg07YjqLlyyx
# Name:		 brubjelke
# Description:	 PL30*3500
# Material:	 STEEL/S355NL
# Tag:	 ID74b622e1-7197-48de-851e-d7b153a3e9e3
# Type:		 PL30*3500
#
# Ifc type:	 IfcPlate
# Guid:		 19ChnIS$1C3xnLV$KvcKqC
# Name:		 brubjelke
# Description:	 PL25*2200
# Material:	 STEEL/S355NL
# Tag:	 ID9f03acc8-ac69-4fc4-914e-3db483c11a1d
# Type:		 PL25*2200
#
# Ifc type:	 IfcPlate
# Guid:		 23pXLUsMv6L9GV3ILijrJF
# Name:		 brubjelke
# Description:	 PL16*5456
# Material:	 STEEL/S355NL
# Tag:	 ID9d636692-c993-450f-811f-6539ecc80803
# Type:		 PL16*5456
#
# Ifc type:	 IfcPlate
# Guid:		 1ANHqEOgXBsgZoAVOmhco_
# Name:		 brubjelke
# Description:	 PL30*3500
# Material:	 STEEL/S355NL
# Tag:	 ID9046417f-948a-421e-a05f-eeddf4c91438
# Type:		 PL30*3500
#
# Ifc type:	 IfcPlate
# Guid:		 3B75CGBw17qQRsVQZeHthi
# Name:		 brubjelke
# Description:	 PL25*2200
# Material:	 STEEL/S355NL
# ...
# Material:	 STEEL/S355NL
# Tag:	 IDe436d5b7-9030-4046-9a05-1669eff78da7
# Type:		 Ø1016*20
#
# Ifc type:	 IfcPile
# Guid:		 0VBaWvPIP9$9zZm9gxfqOa
# Name:		 Pel
# Description:	 Ø1016*20
# Material:	 STEEL/S355NL
# Tag:	 ID107af67e-f14c-446a-b20e-8065a6d637bb
# Type:		 Ø1016*20
#
# Ifc type:	 IfcPile
# Guid:		 3frNcIbEPCv8Ge1jgGx5HB
# Name:		 Pel
# Description:	 Ø1016*20
# Material:	 STEEL/S355NL
# Tag:	 IDce247406-4fdd-44b7-aab5-ebbb90c692cb
# Type:		 Ø1016*20
#
# Ifc type:	 IfcPile
# Guid:		 1YXlBCtKz8ewNQSQv239cr
# Name:		 Pel
# Description:	 Ø1016*20
# Material:	 STEEL/S355NL
# Tag:	 ID8802956e-1062-4438-85ce-ce2e88ac42ad
# Type:		 Ø1016*20
#
# Ifc type:	 IfcPile
# Guid:		 394zrMNuz2$Q5juYlZKl5W
# Name:		 Pel
# Description:	 Ø1016*20
# Material:	 STEEL/S355NL
# Tag:	 ID4f42ebeb-5d44-410a-9876-2f89f95a70bb
# Type:		 Ø1016*20
#
# Ifc type:	 IfcPile
# Guid:		 0nDiPQfLHDJvZ6SG4iDcS4
# Name:		 Pel
# Description:	 Ø1016*20
# Material:	 STEEL/S355NL
# Tag:	 IDad827440-ede2-4df7-a5a5-a7366e9502e2
# Type:		 Ø1016*20
#
# Ifc type:	 IfcPile
# Guid:		 3OetD8nuzCOB$vKFyWLtV8
# Name:		 Pel
# Description:	 Ø1016*20
# Material:	 STEEL/S355NL
# Tag:	 ID5387164a-4ad2-4c0a-99ee-ae88faaa3009
# Type:		 Ø1016*20
#
# Ifc type:	 IfcPile
# Guid:		 1HQVtWZ25EYfLr66uuWHkk
# Name:		 Pel
# Description:	 Ø1016*20
# Material:	 STEEL/S355NL
# Tag:	 ID3ce0cc06-a68d-4fc6-86b4-4fdac8548440
# Type:		 Ø1016*20
#
# Ifc type:	 IfcPile
# Guid:		 3Xdyx11HL42gk2Dmi7SzUp
# Name:		 Pel
# Description:	 Ø1016*20
# Material:	 STEEL/S355NL
# Tag:	 IDa37f24b4-1baf-47cb-a6c2-67a04b57cca9
# Type:		 Ø1016*20
#
# Ifc type:	 IfcPile
# Guid:		 2BFIam59DDdByGpLz8rxm9
# Name:		 Pel
# Description:	 Ø1016*20
# Material:	 STEEL/S355NL
# Tag:	 ID493b461e-5608-4b09-b1bb-ebaccc208416
# Type:		 Ø1016*20
#
# Ifc type:	 IfcPile
# Guid:		 2SYTKsNeP8oOZwuC0OdzVV
# Name:		 Pel
# Description:	 Ø1016*20
# Material:	 STEEL/S355NL
# Tag:	 ID8499d2ac-afd7-4b7d-8d5a-22e852de2f32
# Type:		 Ø1016*20
#
# Ifc type:	 IfcPile
# Guid:		 28sAxA4yn1uPbghvlxItFB
# Name:		 Pel
# Description:	 Ø1016*20
# Material:	 STEEL/S355NL
# Tag:	 IDf10fb217-df7b-4cfb-aad3-7c1f7426dfab
# Type:		 Ø1016*20
#
# Ifc type:	 IfcPile
# Guid:		 2azNLsloP26gim$aYR$7Ts
# Name:		 Pel
# Description:	 Ø1016*20
# Material:	 STEEL/S355NL
# Tag:	 ID6b6b8a2d-6d7a-4485-abd1-2da7b4f01ed9
# Type:		 Ø1016*20
#
# Ifc type:	 IfcPile
# Guid:		 2NY3GV5bHDoOnHclHiF8lp
# Name:		 Pel
# Description:	 Ø1016*20
# Material:	 STEEL/S355NL
# Tag:	 ID3b89b520-ff0f-4daa-8a35-c17656a6c8fc
# Type:		 Ø1016*20
#
# Ifc type:	 IfcPile
# Guid:		 2PscbWnGL0VfTbTGrQMreS
# Name:		 Pel
# Description:	 Ø1016*20
# Material:	 STEEL/S355NL
# Tag:	 ID5b4c162c-fdbd-44ac-b924-cdc544e36e37
# Type:		 Ø1016*20
#
# Ifc type:	 IfcPile
# Guid:		 3n7XvyWC593g6GdukO000y
# Name:		 Pel
# Description:	 Ø1016*20
# Material:	 STEEL/S355NL
# Tag:	 ID3ac2df36-4302-47a8-910c-1c285e33d91b
# Type:		 Ø1016*20
#
# Ifc type:	 IfcPile
# Guid:		 2eTjX80fH57Pr_vWjPRGA3
# Name:		 Pel
# Description:	 Ø1016*20
# Material:	 STEEL/S355NL
# Tag:	 ID7359394e-d157-485f-9fd2-d8a6fef4f622
# Type:		 Ø1016*20
#
# Ifc type:	 IfcPile
# Guid:		 3WCOtV5az8Ne95L4Xl0UTY
# Name:		 Pel
# Description:	 Ø1016*20
# Material:	 STEEL/S355NL
# Tag:	 IDf5c2c7a4-9552-4d13-b408-6c27dbee314e
# Type:		 Ø1016*20
#
# Ifc type:	 IfcPile
# Guid:		 39AQgOmFD8Ou$27EPbw3x9
# Name:		 Pel
# Description:	 Ø1016*20
# Material:	 STEEL/S355NL
# Tag:	 IDa6c171fc-07d3-4726-8c2e-93636a650a23
# Type:		 Ø1016*20
#
# Ifc type:	 IfcPile
# Guid:		 0VBnty3kHCTwR0S6IDmlFW
# Name:		 Pel
# Description:	 Ø1016*20
# Material:	 STEEL/S355NL
# Tag:	 ID8c199fdd-6416-4457-8851-6f2198a26b34
# Type:		 Ø1016*20
#
# Ifc type:	 IfcPile
# Guid:		 0fbhmvPRP6qQ$6b1LNN2ZW
# Name:		 Pel
# Description:	 Ø1016*20
# Material:	 STEEL/S355NL
# Tag:	 ID6b4ba38b-d3da-4d0e-a7c8-fdb6f7d8cf19
# Type:		 Ø1016*20
#
# Ifc type:	 IfcPile
# Guid:		 00RSlVgHfBRw8xeNMqRbX5
# Name:		 Pel
# Description:	 Ø1016*20
# Material:	 STEEL/S355NL
# Tag:	 ID0e201623-8f8f-49d9-9bfa-e5022ccced81
# Type:		 Ø1016*20
#
# Ifc type:	 IfcPile
# Guid:		 0rYeomxIb3WB3mXj$V0lXJ
# Name:		 Pel
# Description:	 Ø1016*20
# Material:	 STEEL/S355NL
# Tag:	 ID8da2f3f8-7a30-45f2-86a5-1826bfa4343b
# Type:		 Ø1016*20
#
# Ifc type:	 IfcPile
# Guid:		 3bXHhlTuv34f0FV4JLURJ0
# Name:		 Pel
# Description:	 Ø1016*20
# Material:	 STEEL/S355NL
# Tag:	 ID2a9a76a6-2847-472f-a730-6b39b2fc9ebd
# Type:		 Ø1016*20
#
# Ifc type:	 IfcPile
# Guid:		 3j6povAj5BGQqMWgZe0xdk
# Name:		 Pel
# Description:	 Ø1016*20
# Material:	 STEEL/S355NL
# Tag:	 ID42b925ed-2191-4f09-80d9-6bada5fac868
# Type:		 Ø1016*20
#
# Ifc type:	 IfcPile
# Guid:		 01$YtBY_z6BPO672Rjx4GJ
# Name:		 Pel
# Description:	 Ø1016*20
# Material:	 STEEL/S355NL
# Tag:	 ID211cc4e3-0d81-47b4-ace6-ebbc7a5b7acf
# Type:		 Ø1016*20
#
# Ifc type:	 IfcPile
# Guid:		 3UGpArFfj8DOLHRL4_spX2
# Name:		 Pel
# Description:	 Ø1016*20
# Material:	 STEEL/S355NL
# Tag:	 ID48748998-8376-4675-977c-46541a54b95c
# Type:		 Ø1016*20
#
# Ifc type:	 IfcPile
# Guid:		 3tK3Q6Qob9ewvku33blDeZ
# Name:		 Pel
# Description:	 Ø1016*20
# Material:	 STEEL/S355NL
# Tag:	 ID1e38f724-62c7-4b46-91ce-722ffeef61fb
# Type:		 Ø1016*20
#
# Ifc type:	 IfcPile
# Guid:		 0DLd70CurAc8nd5rzjKGcx
# Name:		 Pel
# Description:	 Ø1016*20
# Material:	 STEEL/S355NL
# Tag:	 ID7ddcead8-bb16-44c9-8089-b1ec3f1561bf
# Type:		 Ø1016*20
#
# Ifc type:	 IfcPile
# Guid:		 0eyyA7eUjCBO0bj0sIam3X
# Name:		 Pel
# Description:	 Ø1016*20
# Material:	 STEEL/S355NL
# Tag:	 ID827789e3-bd85-4287-9507-97f84db344b7
# Type:		 Ø1016*20
#
# Ifc type:	 IfcPile
# Guid:		 3LEGYjxKP1hOpU6bIYYlsA
# Name:		 Pel
# Description:	 Ø1016*20
# Material:	 STEEL/S355NL
# Tag:	 ID34e4bdb9-5572-4927-8dbc-9382a7d5ee60
# Type:		 Ø1016*20
#
# Ifc type:	 IfcPile
# Guid:		 2SCqLPmTzCoumue5Fa8pj4
# Name:		 Pel
# Description:	 Ø1016*20
# Material:	 STEEL/S355NL
# Tag:	 ID5ca2bcaa-bcaf-464b-8215-dde6e8bccb95
# Type:		 Ø1016*20
#
# Ifc type:	 IfcPile
# Guid:		 2jzql3Xgb97v4vDoMt4IL6
# Name:		 Pel
# Description:	 Ø1016*20
# Material:	 STEEL/S355NL
# Tag:	 ID39872381-c1f3-4c8e-a69a-c50d3338aeca
# Type:		 Ø1016*20
#
# Ifc type:	 IfcPile
# Guid:		 3yC8WDacz1uxLbIUEpAEgg
# Name:		 Pel
# Description:	 Ø1016*20
# Material:	 STEEL/S355NL
# Tag:	 ID54f74574-7288-4698-8136-255221d01ff1
# Type:		 Ø1016*20
#
# Ifc type:	 IfcPile
# Guid:		 2othgdRwLDkPkqC3PSh2JG
# Name:		 Pel
# Description:	 Ø1016*20
# Material:	 STEEL/S355NL
# Tag:	 IDe4090a72-3a0f-45e8-b4c4-acab7b8ae5e1
# Type:		 Ø1016*20
#
# Ifc type:	 IfcPile
# Guid:		 3rhnEnRwr53RqH8PxvH6LZ
# Name:		 Pel
# Description:	 Ø1016*20
# Material:	 STEEL/S355NL
# Tag:	 ID67cc2f2b-71dd-4e52-898a-852b3bfa203c
# Type:		 Ø1016*20
#
# Ifc type:	 IfcPile
# Guid:		 09V5PMXu16UekpBNDT2V7w
# Name:		 Pel
# Description:	 Ø1016*20
# Material:	 STEEL/S355NL
# Tag:	 ID3dc65fc6-f312-4be2-82ee-d2d01132b1bc
# Type:		 Ø1016*20
#
# Ifc type:	 IfcPile
# Guid:		 0_BL4B65b2FBljoBwrg6Dr
# Name:		 Pel
# Description:	 Ø1016*20
# Material:	 STEEL/S355NL
# Tag:	 ID96e10d5a-d11f-4de6-a99a-6d05425e9d1f
# Type:		 Ø1016*20
#
# Ifc type:	 IfcPile
# Guid:		 3pa1j$L05CtRPYNH25_87J
# Name:		 Pel
# Description:	 Ø1016*20
# Material:	 STEEL/S355NL
# Tag:	 ID5c5f446e-4dbf-4aef-959a-21fdf5617d0e
# Type:		 Ø1016*20
#
# Ifc type:	 IfcPile
# Guid:		 2u5Qo7EBnBKwd31D2HiG8k
# Name:		 Pel
# Description:	 Ø1016*20
# Material:	 STEEL/S355NL
# Tag:	 IDddae225d-b369-42e5-a182-fc0ca3c39ca5
# Type:		 Ø1016*20
#
# Ifc type:	 IfcPile
# Guid:		 2TNW3tyNbAdADOhBap7YPw
# Name:		 Pel
# Description:	 Ø1016*20
# Material:	 STEEL/S355NL
# Tag:	 IDeaea08db-8fb2-4549-b182-7dc3180dfbba
# Type:		 Ø1016*20
#
# Ifc type:	 IfcPile
# Guid:		 0TZ1PccrPFjAymMVsYqNaj
# Name:		 Pel
# Description:	 Ø1016*20
# Material:	 STEEL/S355NL
# Tag:	 ID4954a0f9-cb50-4e4d-8f93-ccaef0265e01
# Type:		 Ø1016*20
#
# Ifc type:	 IfcPile
# Guid:		 3V8aTkEhH8RvbVJA9b2DqZ
# Name:		 Pel
# Description:	 Ø1016*20
# Material:	 STEEL/S355NL
# Tag:	 IDa932ba27-8800-4f27-8727-3871e13cf86d
# Type:		 Ø1016*20
#
# Ifc type:	 IfcPile
# Guid:		 3nM8dRExD5ng7rIJ4JM9xe
# Name:		 Pel
# Description:	 Ø1016*20
# Material:	 STEEL/S355NL
# Tag:	 ID33cb344a-c3a9-4dd7-bff5-aaacc0126bfc
# Type:		 Ø1016*20
#
# Ifc type:	 IfcPile
# Guid:		 3maFcgE793FfpZOsLzzD9V
# Name:		 Pel
# Description:	 Ø1016*20
# Material:	 STEEL/S355NL
# Tag:	 ID41b194ae-8c2b-4b11-be51-48b312f0c9ff
# Type:		 Ø1016*20
#
# Ifc type:	 IfcPile
# Guid:		 2YNjbiFNfAIQlIyXGnJE40
# Name:		 Pel
# Description:	 Ø1016*20
# Material:	 STEEL/S355NL
# Tag:	 IDc0417e5d-41c2-441d-bc9c-0d43f400b2e3
# Type:		 Ø1016*20
#
# Ifc type:	 IfcPile
# Guid:		 116MhFsW92dg3F1mo4zRWZ
# Name:		 Pel
# Description:	 Ø1016*20
# Material:	 STEEL/S355NL
# Tag:	 IDaf6c53ff-1a75-4cae-ac21-886d9c89162a
# Type:		 Ø1016*20
#
# Ifc type:	 IfcPile
# Guid:		 06ayM_Q7T8aQr4x4zhCi4K
# Name:		 Pel
# Description:	 Ø1016*20
# Material:	 STEEL/S355NL
# Tag:	 IDcff3926e-021d-4ba5-9534-4a179fbfa2e2
# Type:		 Ø1016*20
#
# Ifc type:	 IfcPile
# Guid:		 0qsmprMB9CcxT9gezhUsSb
# Name:		 Pel
# Description:	 Ø1016*20
# Material:	 STEEL/S355NL
# Tag:	 IDfdd62854-dd05-4cff-90d3-f2d48bd66b48
# Type:		 Ø1016*20
#
# Ifc type:	 IfcPile
# Guid:		 2mC01_THf1FheIP4XOvwWq
# Name:		 Pel
# Description:	 Ø1016*20
# Material:	 STEEL/S355NL
# Tag:	 IDcd4dcf87-4888-4237-8541-7997ee3ed516
# Type:		 Ø1016*20
#
# Ifc type:	 IfcPile
# Guid:		 1BLluT2Qb1ouETQboYEgmx
# Name:		 Pel
# Description:	 Ø1016*20
# Material:	 STEEL/S355NL
# Tag:	 ID3ccaf366-5af4-4f7c-976d-74d2f9bc2837
# Type:		 Ø1016*20
#
# Ifc type:	 IfcPile
# Guid:		 1v6$L9qTn81x2QXvHU4IHV
# Name:		 Pel
# Description:	 Ø1016*20
# Material:	 STEEL/S355NL
# Tag:	 ID19473291-2856-4121-bb40-6626310a0994
# Type:		 Ø1016*20
#
# Ifc type:	 IfcPile
# Guid:		 0wNJnXHbn3hPah$qKZhZXY
# Name:		 Pel
# Description:	 Ø1016*20
# Material:	 STEEL/S355NL
# Tag:	 ID11dfe8e8-79a3-4fa2-98de-4454476b0e3d
# Type:		 Ø1016*20
#
# Ifc type:	 IfcPile
# Guid:		 0qCi6lNovDOvHfsuryGHcj
# Name:		 Pel
# Description:	 Ø1016*20
# Material:	 STEEL/S355NL
# Tag:	 IDebadd883-8037-45e4-b6a3-5e0b33a3e0d3
# Type:		 Ø1016*20
#
# Ifc type:	 IfcPile
# Guid:		 2SY$WkYjf0ZwBF$6A5Gsro
# Name:		 Pel
# Description:	 Ø1016*20
# Material:	 STEEL/S355NL
# Tag:	 ID24f96732-d058-40a5-9efe-695638b71764
# Type:		 Ø1016*20
#
# Ifc type:	 IfcPile
# Guid:		 2J14DIw7vFxuEeOSg2bSjN
# Name:		 Pel
# Description:	 Ø1016*20
# Material:	 STEEL/S355NL
# Tag:	 ID0094ef6c-da32-435c-8900-c9d0c3c74a1c
# Type:		 Ø1016*20
#
# Ifc type:	 IfcPile
# Guid:		 3LOLKzSnvBLuiNimxwdF9J
# Name:		 Pel
# Description:	 Ø1016*20
# Material:	 STEEL/S355NL
# Tag:	 IDe08fb649-94dc-4283-9d53-759a0245966f
# Type:		 Ø1016*20
#
# Ifc type:	 IfcPile
# Guid:		 2nRyu3QtT4dw2znetYw9VW
# Name:		 Pel
# Description:	 Ø1016*20
# Material:	 STEEL/S355NL
# Tag:	 ID911f7ad9-a00a-438b-8f48-718e7b714b9c
# Type:		 Ø1016*20
#
# Ifc type:	 IfcPile
# Guid:		 1Gky9lRTL6n8cp_Q6kItWy
# Name:		 Pel
# Description:	 Ø1016*20
# Material:	 STEEL/S355NL
# Tag:	 IDdf78c0e7-9c01-4494-a909-b7fee1d9af6b
# Type:		 Ø1016*20
#
# Ifc type:	 IfcPile
# Guid:		 2Jh_GWOj5CYRsjDJBbLWd5
# Name:		 Pel
# Description:	 Ø1016*20
# Material:	 STEEL/S355NL
# Tag:	 ID83d7b39b-83bb-4800-8796-f41ee6798554
# Type:		 Ø1016*20
#
# Ifc type:	 IfcPile
# Guid:		 0z85cWhsLERAKuyiu8Bfu7
# Name:		 Pel
# Description:	 Ø1016*20
# Material:	 STEEL/S355NL
# Tag:	 ID6be852e3-b221-42d6-8f50-db7a9db0c8a8
# Type:		 Ø1016*20
#
# Ifc type:	 IfcPile
# Guid:		 3RrMYfzzD0XhFiLfN67fuT
# Name:		 Pel
# Description:	 Ø1016*20
# Material:	 STEEL/S355NL
# Tag:	 ID4129e8fa-c768-46a1-a24f-3e3599365bbf
# Type:		 Ø1016*20
#
# Ifc type:	 IfcPile
# Guid:		 3Hcqu6FPzCtAIRRQcmFPTu
# Name:		 Pel
# Description:	 Ø1016*20
# Material:	 STEEL/S355NL
# Tag:	 ID21e026d0-8fc5-4ee0-a5cd-805e15d98795
# Type:		 Ø1016*20
#
# Ifc type:	 IfcPile
# Guid:		 00mHfyOz161ftIR_9WNFK7
# Name:		 Pel
# Description:	 Ø1016*20
# Material:	 STEEL/S355NL
# Tag:	 IDb11afd18-bb0b-41bd-8c9e-979931347891
# Type:		 Ø1016*20
#
# Ifc type:	 IfcPile
# Guid:		 39v1L0_Ij5eRYujUnZICPD
# Name:		 Pel
# Description:	 Ø1016*20
# Material:	 STEEL/S355NL
# Tag:	 IDbe3de669-e838-46ac-ad01-686f5d925e5a
# Type:		 Ø1016*20
#
# Ifc type:	 IfcPile
# Guid:		 2z32MLa4P1lglyKZOPMoiR
# Name:		 Pel
# Description:	 Ø1016*20
# Material:	 STEEL/S355NL
# Tag:	 ID0fa2bffa-f4a7-4e8e-ac39-b64793141e03
# Type:		 Ø1016*20
#
# Ifc type:	 IfcPile
# Guid:		 2_m1FTgYv36wodyOb23L5m
# Name:		 Pel
# Description:	 Ø1016*20
# Material:	 STEEL/S355NL
# Tag:	 ID6dbd7744-2663-47dc-af94-f711970b2de0
# Type:		 Ø1016*20
#
# Ifc type:	 IfcPile
# Guid:		 2zzmVZWCn4vfAOKqKMqzYJ
# Name:		 Pel
# Description:	 Ø1016*20
# Material:	 STEEL/S355NL
# Tag:	 ID5201064e-2219-4f54-a2a9-91b99050198b
# Type:		 Ø1016*20
#
# Ifc type:	 IfcPile
# Guid:		 1iiDFk7CL4hPYhq2ZX$OaI
# Name:		 Pel
# Description:	 Ø1016*20
# Material:	 STEEL/S355NL
# Tag:	 ID90d96781-d53b-4249-aa4d-9eb655598efb
# Type:		 Ø1016*20
#
# Ifc type:	 IfcPile
# Guid:		 0SwAy3Cw97ag8OtHwsgzzQ
# Name:		 Pel
# Description:	 Ø1016*20
# Material:	 STEEL/S355NL
# Tag:	 IDfebbb82d-d59a-4124-8652-8e76aa642184
# Type:		 Ø1016*20
#
# Ifc type:	 IfcPile
# Guid:		 1_LOKYlAv38AK7u1HCyFY6
# Name:		 Pel
# Description:	 Ø1016*20
# Material:	 STEEL/S355NL
# Tag:	 ID5de29ef3-72aa-4b67-a5de-c32373dacc74
# Type:		 Ø1016*20
#
# Ifc type:	 IfcPile
# Guid:		 1nMYq8r0z0$gHhoTSiMuiM
# Name:		 Pel
# Description:	 Ø1016*20
# Material:	 STEEL/S355NL
# Tag:	 ID76f93b51-48db-4364-b2f0-af1526fdfb4d
# Type:		 Ø1016*20
#
# Ifc type:	 IfcPile
# Guid:		 2zjr10$156DeAxoNPznhQ2
# Name:		 Pel
# Description:	 Ø1016*20
# Material:	 STEEL/S355NL
# Tag:	 IDdfcf396c-e5fc-4f9f-879b-9349e2c754ce
# Type:		 Ø1016*20
#
# Ifc type:	 IfcPile
# Guid:		 1JoYVPM9fBnOE5QN7I46Rg
# Name:		 Pel
# Description:	 Ø1016*20
# Material:	 STEEL/S355NL
# Tag:	 ID7b773182-990b-40a2-a794-d9dd988ea4bd
# Type:		 Ø1016*20
#
# Ifc type:	 IfcPile
# Guid:		 3EqVkRMXX6Gvy4khXxnS5e
# Name:		 Pel
# Description:	 Ø1016*20
# Material:	 STEEL/S355NL
# Tag:	 ID247a4104-4b5f-4875-9e73-725722d8347d
# Type:		 Ø1016*20
#
# Ifc type:	 IfcPile
# Guid:		 00MUhUBi1DkBbiGDo8jCa$
# Name:		 Pel
# Description:	 Ø1016*20
# Material:	 STEEL/S355NL
# Tag:	 ID85d2d1c5-ff56-466f-90da-72ecff4f434c
# Type:		 Ø1016*20
#
# Ifc type:	 IfcPile
# Guid:		 378Si5SrLCmRu8jRCuNfgE
# Name:		 Pel
# Description:	 Ø1016*20
# Material:	 STEEL/S355NL
# Tag:	 ID66d55dbd-3fff-47d4-b19a-600d893de366
# Type:		 Ø1016*20
#
# Ifc type:	 IfcPile
# Guid:		 1YRbM8hRzDhvKB4XvM4OGU
# Name:		 Pel
# Description:	 Ø1016*20
# Material:	 STEEL/S355NL
# Tag:	 ID276319d0-1b88-4dac-b618-6513401f089f
# Type:		 Ø1016*20
#
# Ifc type:	 IfcPile
# Guid:		 0GnBPisqfEch8W6KukxyaW
# Name:		 Pel
# Description:	 Ø1016*20
# Material:	 STEEL/S355NL
# Tag:	 ID34ab9696-d640-44bd-8e4b-2cbd2f0742a7
# Type:		 Ø1016*20
#
# Ifc type:	 IfcPile
# Guid:		 39OBumFF57EuZ6iOlaAN1Z
# Name:		 Pel
# Description:	 Ø1016*20
# Material:	 STEEL/S355NL
# Tag:	 IDbc83cb70-8170-4906-9910-b91393f9866c
# Type:		 Ø1016*20
#
# Ifc type:	 IfcPile
# Guid:		 21g9C5Egr9IvsfbXxL7j_K
# Name:		 Pel
# Description:	 Ø1016*20
# Material:	 STEEL/S355NL
# Tag:	 ID02b7f8e7-0594-45fa-96c3-20cb37410dee
# Type:		 Ø1016*20
#
# Ifc type:	 IfcPile
# Guid:		 2kzrIBQOnAhgf9oSePL980
# Name:		 Pel
# Description:	 Ø1016*20
# Material:	 STEEL/S355NL
# Tag:	 ID5b6923fe-1af5-46e3-9ad6-dab0cc33fb29
# Type:		 Ø1016*20
#
# Ifc type:	 IfcPile
# Guid:		 3o_2gKDCb4yx7p_4IUuD4T
# Name:		 Pel
# Description:	 Ø1016*20
# Material:	 STEEL/S355NL
# Tag:	 IDaed545c7-3888-4829-9a0c-8c534ab11111
# Type:		 Ø1016*20
#
# Ifc type:	 IfcPile
# Guid:		 3FQwCFgyP7Gejnn8ISnxV4
# Name:		 Pel
# Description:	 Ø1016*20
# Material:	 STEEL/S355NL
# Tag:	 IDdaa121e0-f30a-46e0-88be-a2c69e9c36ed
# Type:		 Ø1016*20
#
# Ifc type:	 IfcPile
# Guid:		 0bvVejHab4vOcp9SWGMhKe
# Name:		 Pel
# Description:	 Ø1016*20
# Material:	 STEEL/S355NL
# Tag:	 ID93f7777a-d5af-4f13-bb1f-66cb01892165
# Type:		 Ø1016*20
#
# Ifc type:	 IfcColumn
# Guid:		 2KmW_6U$n5xxAhhwI2r6mh
# Name:		 søyle
# Description:	 CVzXBSTRmUOX7dus1LM4lw_0
# Material:	 CONCRETE/B45
# Tag:	 IDbbdb2050-d18c-4e25-b9a9-9dd1955d6a49
# Type:		 CVzXBSTRmUOX7dus1LM4lw_0
#
# Ifc type:	 IfcColumn
# Guid:		 31VbOhPVfCOAC0BN7AoZ04
# Name:		 søyle
# Description:	 CVzXBSTRmUOX7dus1LM4lw_1
# Material:	 CONCRETE/B45
# Tag:	 ID4fae5554-13ee-43b8-9cf8-e39a06179a71
# Type:		 CVzXBSTRmUOX7dus1LM4lw_1
#
# Ifc type:	 IfcColumn
# Guid:		 3_pFayzUn3P9dh6n$RRv7f
# Name:		 søyle
# Description:	 CVzXBSTRmUOX7dus1LM4lw_2
# Material:	 CONCRETE/B45
# Tag:	 ID4a05c032-e217-4c85-97c1-8ccdda46a44a
# Type:		 CVzXBSTRmUOX7dus1LM4lw_2
#
# Ifc type:	 IfcColumn
# Guid:		 1oZBCB48HC2AeX3kz$0o0G
# Name:		 søyle
# Description:	 CVzXBSTRmUOX7dus1LM4lw_3
# Material:	 CONCRETE/B45
# Tag:	 ID664248df-d9c1-4fa5-ac05-53ebfb1ad308
# Type:		 CVzXBSTRmUOX7dus1LM4lw_3
#
# Ifc type:	 IfcColumn
# Guid:		 1j30LtmWf2AfHBY9BsJSeC
# Name:		 søyle
# Description:	 CVzXBSTRmUOX7dus1LM4lw_4
# Material:	 CONCRETE/B45
# Tag:	 ID22f1e9c5-05b5-4c39-ba21-c24b7cb2c7a6
# Type:		 CVzXBSTRmUOX7dus1LM4lw_4
#
# Ifc type:	 IfcColumn
# Guid:		 0Gdm3DtsH3mQ5KaospUH2b
# Name:		 søyle
# Description:	 CVzXBSTRmUOX7dus1LM4lw_5
# Material:	 CONCRETE/B45
# Tag:	 IDdb0be44e-5470-485c-8728-ac99b0d7c62d
# Type:		 CVzXBSTRmUOX7dus1LM4lw_5
#
# Ifc type:	 IfcColumn
# Guid:		 1V6yBSz$vE5vRuqGqnaTfd
# Name:		 søyle
# Description:	 CVzXBSTRmUOX7dus1LM4lw_6
# Material:	 CONCRETE/B45
# Tag:	 IDd851cd44-4389-495b-af74-94e59c6849aa
# Type:		 CVzXBSTRmUOX7dus1LM4lw_6

# %%
unique_product_names = set([(product.Name,product.is_a()) for product in products])
print(unique_product_names)
# Out:
# {('Underbygning', 'IfcBuildingStorey'), ('brubjelke', 'IfcPlate'), ('Pel', 'IfcPile'), ('Landkar', 'IfcWall'), ('Overbygning', 'IfcBuildingStorey'), ('Bru', 'IfcBuildingStorey'), ('Markusplassen', 'IfcSite'), ('Landkar', 'IfcFooting'), ('endeskjørt', 'IfcSlab'), ('Storbruen', 'IfcBuilding'), ('søyle', 'IfcColumn'), ('Fundament', 'IfcFooting')}

# %%
## Ordbok 
v440_dict = {
    
    "Underbygning":{"uri":"http://rdf.vegdata.no/v440-owl#Underbygning",
                    "label":"Underbygning"},
    "Pel":{"uri":"http://rdf.vegdata.no/v440-owl#Grunnen_Peler",
           "label":"Peler"},
    "Fundament":{"uri":"http://rdf.vegdata.no/v440-owl#Pilar_Fundament",
                 "label":"Fundament"},
    "Søyle":{"uri":"http://rdf.vegdata.no/v440-owl#Pilar_Soyle_skive",
             "label":"Søyle/skive"},
    "Storbruen":{"uri":"http://rdf.vegdata.no/v440-owl#Bjelkebru_platebaerere_konstant_hoyde",
                 "label":"Bjelkebru platebærere konstant høyde sveiset med sveiseskjøter uten samvirke"},
    "Landkar":{"uri":"http://rdf.vegdata.no/v440-owl#Landkar",
               "label":"Landkar"},
    "Markusplassen":{"uri":"http://markusplassen.no/v440/",
                     "label":"Nordlenningen"},
    "Bru":{"uri":"http://rdf.vegdata.no/v440-owl#Brudekke_Slitelag_Brudekke_sek_baeresystem",
           "label":"Bru i fylling"},
    "endeskjørt":{"uri":"http://rdf.vegdata.no/V440/v440-owl#Buekonstruksjon_Langsgaende_bjelke",
                  "label":"Langsgående bjelke"},
    "Overbygning":{"uri":"http://rdf.vegdata.no/v440-owl#Overbygning",
                   "label":"Overbygning"},
    "brubjelke":{"uri":"http://rdf.vegdata.no/V440/v440-owl#Buekonstruksjon_Langsgaende_bjelke",
                   "label":"Langsgående bjelke"},
    "CONCRETE/B45":{"uri":"http://rdf.vegdata.no/v440-owl#Konstruksjonsmaterialer_Materialtyper_Betong",
                   "label":"Betong, plasstøpt"},
    'STEEL/S355NL':{"uri":"http://rdf.vegdata.no/V440/v440-owl#Utstyr_Fugetyper_Stalplatefuge_slepeplate",
                   "label":"Stålplatefuge, slepeplate, fjærbelastet"}
}

# %%
def get_v440_uris(label):
    url = "http://rdfspatial.vegdata.no:7200/repositories/V440"
    query ="""SELECT ?uri ?label
                WHERE {
                # ?uri rdfs:label ?label .
                FILTER(STRSTARTS(?label,"%s"))
                }"""%label
    r = requests.get(url, params = {"Accept": "application/json", 'query': query})
    return r.json()["results"]["bindings"]
get_v440_uris("Underbygning")
# Out:
# [{'label': {'xml:lang': 'no', 'type': 'literal', 'value': 'Underbygning'},
#   'uri': {'type': 'uri',
#    'value': 'http://rdf.vegdata.no/v440-owl#Underbygning'}},
#  {'label': {'xml:lang': 'no', 'type': 'literal', 'value': 'Underbygning'},
#   'uri': {'type': 'uri',
#    'value': 'http://rdf.vegdata.no/V440/v440-owl#Underbygning'}}]

# %%
## Helper functions to classify IFC models with v440 (or other classifications)
# ref. NS8360 -- classifying IFC models 

# function for creating ifc_guid
create_guid = lambda: ios.guid.compress(uuid.uuid1().hex)

v440baseUrl = 'http://rdf.vegdata.no/V440/v440-owl'
# create v440 classification
# Is used to represent the v440 library in an Ifc file. There should be one and only one instance with Name “v440”.
# docs: http://www.buildingsmart-tech.org/ifc/IFC2x3/TC1/html/ifcexternalreferenceresource/lexical/ifcclassification.htm
v440_classification = file.createIfcClassification(v440baseUrl,'nb-NO',None,'Håndbok V440')
print(v440_classification)

# create v440 classification reference in ifc according to NS8360 level 2 
# The classification reference is where you store the actual classification. 
# There should be one and only one classification reference for each classification used.
# docs: http://www.buildingsmart-tech.org/ifc/IFC2x3/TC1/html/ifcexternalreferenceresource/lexical/ifcclassificationreference.htm
def create_v440_classification_reference(uri,label):
    tag = "#{}".format(uri.split("#")[0])
    return file.createIfcClassificationReference(uri, tag, label, v440_classification)

# Create the IfcRelAccociatesClassification based on an NS3451 classification reference
# Used to create the actual relationship between the classification item and the objects being classified. 
# docs: http://www.buildingsmart-tech.org/ifc/IFC2x3/TC1/html/ifckernel/lexical/ifcrelassociatesclassification.htm
def classify_ifc_with_v440(objects,uri,label):
    owner_history = objects[0].OwnerHistory
    name = 'Handbok v440'
    classification = create_v440_classification_reference(uri,label)

    return file.createIfcRelAssociatesClassification(create_guid(),owner_history,name,None,objects,classification)
# Out:
# #319932=IfcClassification('http://rdf.vegdata.no/V440/v440-owl','nb-NO',$,'Håndbok V440')

# %%
## Klassifisere broe elementer
def classify_element(element):
